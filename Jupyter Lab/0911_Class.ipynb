# %%
# 외부를 클릭해서 이스케이프 모드
# b : 셀 추가 dd : 셀 삭제 c : 셀 복사 v : 셀 붙여넣기

# %%
import pandas as pd
import numpy as np

# %%
import gdown

# %%
dir(gdown)
# Out:
# ['__author__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'cached_download',
#  'download',
#  'download_folder',
#  'extractall',
#  'md5sum',
#  'parse_url']

# %%
gdown.download('https://bit.ly/3RhoNho', 'ns_202104.csv', quiet=False)
# Out:
# Downloading...
# From: https://bit.ly/3RhoNho
# To: C:\work\ns_202104.csv
# 100%|█████████████████████████████████████████████████████████████████████████████| 57.6M/57.6M [00:16<00:00, 3.56MB/s]
# 'ns_202104.csv'

# %%
df = pd.read_csv('https://bit.ly/3RhoNho')
# Out:
# C:\Users\TaeHwan Lim\AppData\Local\Temp\ipykernel_14768\369920610.py:1: DtypeWarning: Columns (5,6,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('https://bit.ly/3RhoNho')

# %%
df.head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자  Unnamed: 13
# 0     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 1     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 2     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 3     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 4     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN

# %%
df.shape
# Out:
# (401682, 14)

# %%
len(df.columns)
df.shape[1]
df.columns.size-1
# Out:
# 13

# %%
# 슬라이싱
# 시작 : 가져오고자 하는 곳

# %%
df.iloc[:,:-1].head() #[:,:13] / [:,:df.columns.size-1] / [:,np.arange(13)]
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 1     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 2     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 3     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 4     NaN  NaN  NaN    NaN     1     0  2021-03-19

# %%
df.columns[:-1]
# Out:
# Index(['번호', '도서명', '저자', '출판사', '발행년도', 'ISBN', '세트 ISBN', '부가기호', '권',
#        '주제분류번호', '도서권수', '대출건수', '등록일자'],
#       dtype='object')

# %%
[True]*13+[False]
# Out:
# [True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False]

# %%
~(df.columns==df.columns[-1])
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True, False])

# %%
np.arange(10) == 1
# Out:
# array([False,  True, False, False, False, False, False, False, False,
#        False])

# %%
df.loc[:,'번호':'등록일자'].head() #[:,df.columns[:-1]] / [:,[True]*13+[False]]
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 1     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 2     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 3     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 4     NaN  NaN  NaN    NaN     1     0  2021-03-19

# %%
df.loc[:,~(df.columns==df.columns[-1])].head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 1     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 2     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 3     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 4     NaN  NaN  NaN    NaN     1     0  2021-03-19

# %%
df.loc[:,df.columns != df.columns[-1]].head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 1     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 2     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 3     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 4     NaN  NaN  NaN    NaN     1     0  2021-03-19

# %%
df.drop(columns=['Unnamed: 13']).head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 1     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 2     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 3     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 4     NaN  NaN  NaN    NaN     1     0  2021-03-19

# %%
df.drop(columns=df.columns[-1]).head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 1     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 2     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 3     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 4     NaN  NaN  NaN    NaN     1     0  2021-03-19

# %%
df.drop(['Unnamed: 13'],axis=1).head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 1     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 2     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 3     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 4     NaN  NaN  NaN    NaN     1     0  2021-03-19

# %%
df.drop(['Unnamed: 13'],axis=1,inplace=True) #inplace : 데이터를 아예 바꾸는거
df.head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 1     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 2     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 3     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 4     NaN  NaN  NaN    NaN     1     0  2021-03-19

# %%
# df.drop(df.columns[-1],axis=1,inplace=True)
# df.head()

# %%
#null, None, NaN, na
#null == '', None == empty, NaN == Not a Number, na == Not Acceptible

# %%
pd.Series(np.array([np.nan, None, 1, 2]))
pd.DataFrame(np.array([np.nan, None, 1, 2])).isna()
pd.DataFrame(np.array([np.nan, None, 1, 2])).isnull()
pd.DataFrame(np.array([np.nan, None, 1, 2])).dropna()
# Out:
#    0
# 2  1
# 3  2

# %%
df
# Out:
#             번호                    도서명                저자    출판사  발행년도  \
# 0            1                인공지능과 흙            김동훈 지음    민음사  2021
# 1            2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021
# 2            3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021
# 3            4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021
# 4            5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021
# ...        ...                    ...               ...    ...   ...
# 401677  401678                韓國現代詩大系            채만묵 編著  한국문화사  1996
# 401678  401679                  뉴 웨이브        제임스 모나코 지음    한나래  1996
# 401679  401680           (최인훈 장편소설)화두            최인훈 지음    민음사  1994
# 401680  401681           독일 문학과 세계 문학            吳漢鎭 編著     벽호  1995
# 401681  401682             참으로 소중한 생각            김일상 지음    동문사  1995
#
#                  ISBN          세트 ISBN 부가기호    권   주제분류번호  도서권수  대출건수  \
# ...

# %%
df.shape[0] - df.dropna().shape[0]
# Out:
# 365855

# %%
df.shape[-1] - df.dropna(axis=1).shape[1]
# Out:
# 8

# %%
#df.dropna(how="any").shape[0] #'all' 해당 행이 전부 na일때 지우는 거 / 'any' na가 있으면 지우는 거

# %%
df.dropna(how="all")
df.dropna(how="any")
df.dropna(how="all",axis=1)
df.dropna(thresh=8).shape[0]
# Out:
# 401681

# %%
df
# Out:
#             번호                    도서명                저자    출판사  발행년도  \
# 0            1                인공지능과 흙            김동훈 지음    민음사  2021
# 1            2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021
# 2            3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021
# 3            4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021
# 4            5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021
# ...        ...                    ...               ...    ...   ...
# 401677  401678                韓國現代詩大系            채만묵 編著  한국문화사  1996
# 401678  401679                  뉴 웨이브        제임스 모나코 지음    한나래  1996
# 401679  401680           (최인훈 장편소설)화두            최인훈 지음    민음사  1994
# 401680  401681           독일 문학과 세계 문학            吳漢鎭 編著     벽호  1995
# 401681  401682             참으로 소중한 생각            김일상 지음    동문사  1995
#
#                  ISBN          세트 ISBN 부가기호    권   주제분류번호  도서권수  대출건수  \
# ...

# %%
## 컬럼에서 na가 70% 이상인 컬럼을 지우고
## 행의 na 20% 이상인 행일 지우고 남은 na의 개수를 구하면?

# %%
new_df = df.drop(columns =df.columns[df.isna().sum() / df.shape[0] > 0.7])
new_df2 = new_df.loc[new_df.isna().sum(1) / df.shape[1] > 0.2]
new_df2.isna().sum().sum()
# Out:
# 1822

# %%
n_df = df.drop(columns = df.columns[df.isna().sum() / df.shape[0] > 0.7])
# n_df2 = n_df.loc[n_df.isna().sum(axis=1) / n_df.shape[1] > 0.2]
remove_row = (n_df.isna().sum(axis=1) / n_df.shape[1] > 0.2)
# n_df2.isna().sum()
n_df2 = n_df.loc[remove_row, :]
n_df2.isna().sum().sum()
# Out:
# 1822

# %%
df.dropna(axis=1,thresh=(df.isna()*0.3))
# df.dropna(thresh=(df.isna().sum(1)*0.8))
# Out:
#             번호                    도서명                저자    출판사  발행년도  \
# 0            1                인공지능과 흙            김동훈 지음    민음사  2021
# 1            2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021
# 2            3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021
# 3            4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021
# 4            5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021
# ...        ...                    ...               ...    ...   ...
# 401677  401678                韓國現代詩大系            채만묵 編著  한국문화사  1996
# 401678  401679                  뉴 웨이브        제임스 모나코 지음    한나래  1996
# 401679  401680           (최인훈 장편소설)화두            최인훈 지음    민음사  1994
# 401680  401681           독일 문학과 세계 문학            吳漢鎭 編著     벽호  1995
# 401681  401682             참으로 소중한 생각            김일상 지음    동문사  1995
#
#                  ISBN          세트 ISBN 부가기호    권   주제분류번호  도서권수  대출건수  \
# ...

# %%
thresh = int(df.columns.size*0.8)

# %%
np.ceil(df.columns.size*0.8)
# Out:
# 11.0

# %%
df.columns.size - df.isna().sum(1)
# Out:
# 0          9
# 1          9
# 2          9
# 3          9
# 4          9
#           ..
# 401677    12
# 401678    12
# 401679    12
# 401680    12
# 401681    13
# Length: 401682, dtype: int64

# %%
df.dropna(thresh=thresh)
# Out:
#             번호                  도서명                        저자    출판사  발행년도  \
# 30          31               적자의 본질        스테파니 켈튼 지음, 이가영 옮김  비즈니스맵  2021
# 31          32     한 권으로 배우는 음악 이야기                    전기홍 지음   상상출판  2021
# 32          33                인간 관찰       구라하시 마야코 지음, 황세정 옮김  쌤앤파커스  2021
# 33          34               정원의 쓸모     수 스튜어트 스미스 지음, 고정아 옮김     윌북  2021
# 34          35  뇌는 당신이 왜 우울한지 알고 있다  야오나이린 지음, 정세경 옮김, 전홍진 감수   더퀘스트  2021
# ...        ...                  ...                       ...    ...   ...
# 401677  401678              韓國現代詩大系                    채만묵 編著  한국문화사  1996
# 401678  401679                뉴 웨이브                제임스 모나코 지음    한나래  1996
# 401679  401680         (최인훈 장편소설)화두                    최인훈 지음    민음사  1994
# 401680  401681         독일 문학과 세계 문학                    吳漢鎭 編著     벽호  1995
# 401681  401682           참으로 소중한 생각                    김일상 지음    동문사  1995
#
# ...

# %%
df.columns.size - df.isna().sum(axis=1)
# Out:
# 0          9
# 1          9
# 2          9
# 3          9
# 4          9
#           ..
# 401677    12
# 401678    12
# 401679    12
# 401680    12
# 401681    13
# Length: 401682, dtype: int64

# %%
np.sum(df.iloc[:,[1,2,5]].duplicated())
# Out:
# 20191

# %%
np.sum(df.duplicated(subset=['도서명','저자','ISBN']))
# Out:
# 20191

# %%
## groupby : split -> apply -> combine
