# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from collections import Counter
from sklearn.model_selection import train_test_split

from tensorflow.keras.datasets import imdb
from tensorflow.keras.datasets import reuters
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization, Flatten, Embedding, Dropout, Conv1D, MaxPooling1D
from tensorflow.keras.utils import pad_sequences, to_categorical

# %%
word_index = imdb.get_word_index()
index_word = {v:k for k,v in word_index.items()}

# %%
(X_, y_), (X_test, y_test) = imdb.load_data()

# %%
index_word.get(X_[0][0])
# Out:
# 'the'

# %%
def imdb_comment(x):
    comment = ''
    for word in x:
        comment += index_word.get(word) + ' '
    return comment

# %%
imdb_comment(X_[0])
# Out:
# "the as you with out themselves powerful lets loves their becomes reaching had journalist of lot from anyone to have after out atmosphere never more room titillate it so heart shows to years of every never going villaronga help moments or of every chest visual movie except her was several of enough more with is now current film as you of mine potentially unfortunately of you than him that with out themselves her get for was camp of you movie sometimes movie that with scary but pratfalls to story wonderful that in seeing in character to of 70s musicians with heart had shadows they of here that with her serious to have does when from why what have critics they is you that isn't one will very to as itself with other tricky in of seen over landed for anyone of gilmore's br show's to whether from than out themselves history he name half some br of 'n odd was two most of mean for 1 any an boat she he should is thought frog but of script you not while history he heart to real at barrel but when from one bit then have two of script their with her nobody most that with wasn't to with armed acting watch an for with heartfelt film want an "

# %%
y_[0]
# Out:
# 1

# %%
X_.shape
# Out:
# (25000,)

# %%
pd.Series(X_).apply(len).max()
# Out:
# 2494

# %%
word_set = []
for word in X_:
    word_set.extend(word)

# %%
word_cnt = Counter(word_set)

# %%
word_cnt.most_common(1000)
# Out:
# [(4, 336148),
#  (5, 164097),
#  (6, 163040),
#  (7, 145847),
#  (8, 135708),
#  (9, 107313),
#  (10, 101871),
#  (11, 93934),
#  (12, 79058),
#  (13, 77142),
#  (14, 75974),
#  (15, 69787),
#  (16, 48195),
#  (17, 46927),
#  (18, 44335),
#  (19, 44122),
#  (20, 43564),
#  (21, 42594),
#  (22, 39095),
#  (23, 34188),
#  (24, 30610),
#  (25, 29877),
#  (26, 29425),
#  (27, 29366),
#  (28, 27726),
#  (29, 26952),
#  (30, 26948),
#  (31, 26513),
#  (1, 25000),
#  (32, 23953),
#  (33, 23507),
#  (34, 22539),
#  (35, 21538),
#  (36, 21139),
#  (37, 20599),
#  (38, 20586),
#  (39, 20494),
#  (40, 20272),
#  (41, 18407),
#  (42, 17994),
#  (43, 17759),
#  (44, 17371),
#  (45, 17153),
#  (46, 17092),
#  (48, 16790),
#  (47, 16790),
#  (49, 15743),
#  (50, 15735),
#  (51, 15349),
#  (52, 15100),
#  (53, 14246),
#  (54, 14175),
#  (55, 14062),
#  (56, 13274),
#  (57, 12690),
#  (58, 12682),
#  (59, 12657),
#  (60, 12650),
#  (61, 12492),
#  (62, 12238),
#  (63, 12041),
#  (64, 11915),
#  (65, 11892),
#  (66, 11734),
#  (67, 11460),
#  (68, 11376),
#  (69, 11287),
#  (70, 11120),
#  (71, 10783),
#  (72, 10742),
#  (73, 10644),
#  (74, 9919),
#  (75, 9866),
#  (76, 9758),
#  (854, 719),
#  (859, 717),
#  (857, 717),
#  (858, 717),
#  (855, 717),
#  (856, 717),
#  (860, 716),
#  (862, 714),
#  (861, 714),
#  (863, 712),
#  (864, 712),
#  (866, 711),
#  (865, 711),
#  (868, 710),
#  (867, 710),
#  (870, 709),
#  (869, 709),
#  (871, 707),
#  (872, 705),
#  (873, 704),
#  (874, 702),
#  (875, 701),
#  (876, 698),
#  (877, 697),
#  (878, 695),
#  (879, 695),
#  (880, 694),
#  (881, 694),
#  (882, 692),
#  (883, 690),
#  (884, 689),
#  (885, 686),
#  (886, 685),
#  (888, 683),
#  (887, 683),
#  (889, 682),
#  (890, 681),
#  (891, 678),
#  (892, 677),
#  (893, 676),
#  (895, 675),
#  (894, 675),
#  (896, 672),
#  (898, 671),
#  (900, 671),
#  (897, 671),
#  (899, 671),
#  (901, 670),
#  (902, 669),
#  (903, 667),
#  (904, 666),
#  (905, 666),
#  (906, 664),
#  (908, 663),
#  (907, 663),
#  (913, 662),
#  (910, 662),
#  (912, 662),
#  (909, 662),
#  (911, 662),
#  (915, 661),
#  (914, 661),
#  (916, 661),
#  (918, 660),
#  (917, 660),
#  (921, 657),
#  (919, 657),
#  (920, 657),
#  (922, 655),
#  (923, 654),
#  (926, 653),
#  (924, 653),
#  (925, 653),
#  (928, 651),
#  (927, 651),
#  (931, 650),
#  (930, 650),
#  (929, 650),
#  (932, 648),
#  (933, 647),
#  (936, 645),
#  (937, 645),
#  (938, 645),
#  (935, 645),
#  (934, 645),
#  (939, 644),
#  (940, 643),
#  (941, 642),
#  (943, 641),
#  (942, 641),
#  (944, 640),
#  (946, 639),
#  (945, 639),
#  (947, 638),
#  (948, 638),
#  (949, 637),
#  (950, 637),
#  (951, 636),
#  (952, 635),
#  (953, 634),
#  (954, 633),
#  (955, 633),
#  (956, 632),
#  (957, 632),
#  (958, 631),
#  (960, 630),
#  (961, 630),
#  (959, 630),
#  (964, 629),
#  (963, 629),
#  (962, 629),
#  (966, 628),
#  (965, 628),
#  (968, 626),
#  (967, 626),
#  (969, 626),
#  (970, 623),
#  (973, 622),
#  (972, 622),
#  (971, 622),
#  (974, 621),
#  (978, 620),
#  (977, 620),
#  (976, 620),
#  (975, 620),
#  (979, 614),
#  (981, 614),
#  (980, 614),
#  (984, 613),
#  (982, 613),
#  (983, 613),
#  (985, 612),
#  (986, 612),
#  (987, 611),
#  (988, 610),
#  (989, 610),
#  (990, 609),
#  (991, 608),
#  (994, 607),
#  (992, 607),
#  (995, 607),
#  (993, 607),
#  (997, 606),
#  (996, 606),
#  (998, 604),
#  (999, 601),
#  (1000, 601),
#  (1002, 600),
#  (1001, 600)]

# %%
words = [words for words, _ in word_cnt.most_common(1000)]

# %%
X_[0][0]
# Out:
# 1

# %%
def common_word(x):
    for idx,word in enumerate(x):
        if word not in words: ## most_common(1000)
            x[idx] = 0
    return x

# %%
def remove_zero(x):
    return np.array(x)[np.array(x) > 0]

# %%
X_ = pd.Series(X_).apply(common_word,1).apply(remove_zero,1)

# %%
np.ceil(X_.apply(len).mean()).astype(int)
# Out:
# 183

# %%
def comment_slice(x):
    if len(x) < 183:
        tmp = [0] * (183 - (len(x)))
        x = np.append(x, tmp)
    return x[:183]

# %%
X_ = X_.apply(comment_slice,1)

# %%
X_test = pd.Series(X_test).apply(common_word,1).apply(remove_zero,1).apply(comment_slice,1)

# %%
X_test.apply(len)
# Out:
# 0        183
# 1        183
# 2        183
# 3        183
# 4        183
#         ...
# 24995    183
# 24996    183
# 24997    183
# 24998    183
# 24999    183
# Length: 25000, dtype: int64

# %%
X_train, X_validation, y_train, y_validation = train_test_split(X_, y_)

# %%
X_train_trans = X_train.values[0].reshape(-1,183)
for i in X_train.values[1:]:
    X_train_trans = np.append(X_train_trans,i.reshape(-1,183),0)

# %%
X_validation_trans = X_validation.values[0].reshape(-1,183)
for i in X_validation.values[1:]:
    X_validation_trans = np.append(X_validation_trans,i.reshape(-1,183),0)

# %%
model = Sequential(
[Dense(1024, activation = 'relu', input_shape=(183,)),
BatchNormalization(),
Dense(253, activation = 'relu'),
BatchNormalization(),
Dense(32, activation = 'relu'),
BatchNormalization(),
Dense(1, activation = 'sigmoid')])
# Out:
# WARNING:tensorflow:From C:\Users\user\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics='accuracy')
# Out:
# WARNING:tensorflow:From C:\Users\user\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.fit(X_train_trans, y_train, epochs=20, validation_data=(X_validation_trans,y_validation))
# Out:
# Epoch 1/20
# WARNING:tensorflow:From C:\Users\user\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\user\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 586/586 [==============================] - 4s 5ms/step - loss: 0.7310 - accuracy: 0.5095 - val_loss: 0.7036 - val_accuracy: 0.5059
# Epoch 2/20
# 586/586 [==============================] - 3s 5ms/step - loss: 0.6711 - accuracy: 0.5914 - val_loss: 0.7113 - val_accuracy: 0.5138
# Epoch 3/20
# 586/586 [==============================] - 3s 5ms/step - loss: 0.6458 - accuracy: 0.6237 - val_loss: 0.7366 - val_accuracy: 0.5077
# Epoch 4/20
# 586/586 [==============================] - 3s 5ms/step - loss: 0.6108 - accuracy: 0.6691 - val_loss: 0.7752 - val_accuracy: 0.5101
# Epoch 5/20
# 586/586 [==============================] - 3s 5ms/step - loss: 0.5683 - accuracy: 0.7024 - val_loss: 0.8266 - val_accuracy: 0.5050
# Epoch 6/20
# 586/586 [==============================] - 3s 5ms/step - loss: 0.5042 - accuracy: 0.7570 - val_loss: 0.9296 - val_accuracy: 0.5123
# Epoch 7/20
# 586/586 [==============================] - 3s 5ms/step - loss: 0.4387 - accuracy: 0.7968 - val_loss: 1.0431 - val_accuracy: 0.5136
# Epoch 8/20
# 586/586 [==============================] - 3s 5ms/step - loss: 0.3732 - accuracy: 0.8338 - val_loss: 1.1095 - val_accuracy: 0.5227
# Epoch 9/20
# 586/586 [==============================] - 3s 5ms/step - loss: 0.3282 - accuracy: 0.8602 - val_loss: 1.2581 - val_accuracy: 0.5085
# Epoch 10/20
# 586/586 [==============================] - 3s 5ms/step - loss: 0.2735 - accuracy: 0.8860 - val_loss: 1.3763 - val_accuracy: 0.5107
# Epoch 11/20
# 586/586 [==============================] - 3s 5ms/step - loss: 0.2579 - accuracy: 0.8925 - val_loss: 1.4603 - val_accuracy: 0.5112
# Epoch 12/20
# 586/586 [==============================] - 3s 5ms/step - loss: 0.2195 - accuracy: 0.9104 - val_loss: 1.5601 - val_accuracy: 0.5091
# Epoch 13/20
# 586/586 [==============================] - 3s 5ms/step - loss: 0.2007 - accuracy: 0.9183 - val_loss: 1.6497 - val_accuracy: 0.5163
# Epoch 14/20
# 586/586 [==============================] - 3s 5ms/step - loss: 0.1914 - accuracy: 0.9252 - val_loss: 1.7882 - val_accuracy: 0.5157
# Epoch 15/20
# 586/586 [==============================] - 3s 5ms/step - loss: 0.1731 - accuracy: 0.9298 - val_loss: 1.8044 - val_accuracy: 0.5115
# Epoch 16/20
# 586/586 [==============================] - 3s 5ms/step - loss: 0.1711 - accuracy: 0.9322 - val_loss: 1.8038 - val_accuracy: 0.5186
# Epoch 17/20
# 586/586 [==============================] - 3s 5ms/step - loss: 0.1651 - accuracy: 0.9356 - val_loss: 1.8308 - val_accuracy: 0.5186
# Epoch 18/20
# 586/586 [==============================] - 3s 5ms/step - loss: 0.1483 - accuracy: 0.9433 - val_loss: 1.9520 - val_accuracy: 0.5152
# Epoch 19/20
# 586/586 [==============================] - 3s 5ms/step - loss: 0.1516 - accuracy: 0.9396 - val_loss: 1.9719 - val_accuracy: 0.5182
# Epoch 20/20
# 586/586 [==============================] - 3s 5ms/step - loss: 0.1436 - accuracy: 0.9436 - val_loss: 1.9853 - val_accuracy: 0.5147

# %%
np.where(model.predict(X_train_trans[[1557]]) > 0.5, 1, 0)[0][0], y_train[1557]
# Out:
# 1/1 [==============================] - 0s 33ms/step
# (1, 1)

# %%
np.where(model.predict(X_test[1557].reshape(1,-1)) > 0.5, 1, 0)[0][0], y_test[1557]
# Out:
# 1/1 [==============================] - 0s 37ms/step
# (1, 1)

# %%
comment = """
On 8 April, there will still be six full Premier League match rounds to play, with the possibility of some rearranged games, meaning it is likely the relegation places will not have been decided.

So any decision that ends in a points deduction is virtually certain to be subject to an appeal, even as a pre-emptive strike by the clubs - and that brings the potential for chaos as there is no guarantee any appeal would be heard before the final games of the campaign on 19 May.

Those final-day fixtures? Burnley v Nottingham Forest and Arsenal v Everton.

In terms of actually playing matches, that is when the season ends. But in terms of regulation, the 2023-24 season remains 'live' until the annual general meeting in June when the relegated clubs transfer their certificates. It is this point at which everything has to be determined.
"""

# %%
def remove_words(x):
    x = x.replace('.','')
    x = x.replace(',','')
    x = x.replace('"','')
    x = x.replace('?','')
    x = x.replace('!','')
    x = x.replace("'",'')
    return x

# %%
def imdb_predict(model, comment):
    model = model
    word = []
    for i in comment.split(' '):
        i = remove_words(i)
        if word_index.get(i) != None:
            word.append(word_index.get(i))
    word = common_word(word)
    word = remove_zero(word)
    word = comment_slice(word)
    word = word.reshape(1,-1)
    return np.where(model.predict(word,verbose=0)[0] > 0.5, '긍정', '부정')[0]

# %%
imdb_predict(model,comment)
# Out:
# '부정'

# %%
from tensorflow.keras.layers import Embedding

# %%
model1 = Sequential(
[
    Embedding(1000, 8, input_length=183),
    Flatten(),
    Dense(128,activation='relu'),
    BatchNormalization(),
    Dense(1,activation='sigmoid')
])

# %%
model1.compile(optimizer='adam',loss='binary_crossentropy',metrics='accuracy')

# %%
model1.predict(np.random.randint(1,1001,183).reshape(1,-1))
# Out:
# 1/1 [==============================] - 0s 77ms/step
# array([[0.49550107]], dtype=float32)

# %%
(X_, y_), (X_test, y_test) = imdb.load_data()
X = np.append(X_, X_test, 0)
y = np.append(y_, y_test)

# %%
# pad_sequences(X_test, 200)

# %%
word_index = imdb.get_word_index()
index_word = {v:k for k,v in word_index.items()}

# %%
for idx1, ind_word in enumerate(X):
    for idx2, val in enumerate(ind_word):
        X[idx1][idx2] = index_word.get(X[idx1][idx2])

# %%
word_list = []
for words in X:
    word_list.extend(words)

# %%
word_freq = Counter(word_list).most_common(1000)

# %%
word_to_index = {v:k for k, (v,_) in enumerate(word_freq,1)}

# %%
index_to_word = {v:k for k,v in word_to_index.items()}

# %%
for idx1, ind_word in enumerate(X):
    for idx2, val in enumerate(ind_word):
        if word_to_index.get(X[idx1][idx2]) != None:
            X[idx1][idx2] = word_to_index.get(X[idx1][idx2])
        else:
            X[idx1][idx2] = 0

# %%
X = pd.Series(X).apply(lambda x:np.array(x)[np.array(x)>0]).values

# %%
X = pad_sequences(X,200)

# %%
X_, X_test, y_, y_test = train_test_split(X,y)

# %%
X_train, X_validation, y_train, y_validation = train_test_split(X_, y_)

# %%
y_train = y_train.reshape(-1,1)
y_validation = y_validation.reshape(-1,1)
y_test = y_test.reshape(-1,1)

# %%
model_embed = Sequential(
[
    Embedding(1001, 8, input_length=200),
    Dropout(0.5),
    Flatten(),
    Dense(256,activation='relu'),
    BatchNormalization(),
    Dense(128,activation='relu'),
    BatchNormalization(),
    Dense(10,activation='relu'),
    BatchNormalization(),
    Dense(1,activation='sigmoid')
])

# %%
model_embed.compile(optimizer='adam',loss='binary_crossentropy',metrics='accuracy')

# %%
model_embed.fit(X_train, y_train, epochs=30, validation_data=(X_validation, y_validation))
# Out:
# Epoch 1/30
# 879/879 [==============================] - 6s 5ms/step - loss: 0.6056 - accuracy: 0.6438 - val_loss: 0.3908 - val_accuracy: 0.8221
# Epoch 2/30
# 879/879 [==============================] - 4s 5ms/step - loss: 0.3831 - accuracy: 0.8295 - val_loss: 0.3487 - val_accuracy: 0.8427
# Epoch 3/30
# 879/879 [==============================] - 4s 5ms/step - loss: 0.3524 - accuracy: 0.8449 - val_loss: 0.3417 - val_accuracy: 0.8467
# Epoch 4/30
# 879/879 [==============================] - 4s 5ms/step - loss: 0.3409 - accuracy: 0.8511 - val_loss: 0.3492 - val_accuracy: 0.8446
# Epoch 5/30
# 879/879 [==============================] - 4s 5ms/step - loss: 0.3326 - accuracy: 0.8564 - val_loss: 0.3478 - val_accuracy: 0.8499
# Epoch 6/30
# 879/879 [==============================] - 4s 5ms/step - loss: 0.3221 - accuracy: 0.8625 - val_loss: 0.3421 - val_accuracy: 0.8508
# Epoch 7/30
# 879/879 [==============================] - 4s 5ms/step - loss: 0.3064 - accuracy: 0.8686 - val_loss: 0.3431 - val_accuracy: 0.8459
# Epoch 8/30
# 879/879 [==============================] - 4s 5ms/step - loss: 0.3003 - accuracy: 0.8730 - val_loss: 0.3710 - val_accuracy: 0.8398
# Epoch 9/30
# 879/879 [==============================] - 5s 5ms/step - loss: 0.2896 - accuracy: 0.8754 - val_loss: 0.3637 - val_accuracy: 0.8437
# Epoch 10/30
# 879/879 [==============================] - 4s 5ms/step - loss: 0.2802 - accuracy: 0.8807 - val_loss: 0.3537 - val_accuracy: 0.8465
# Epoch 11/30
# 879/879 [==============================] - 4s 5ms/step - loss: 0.2682 - accuracy: 0.8847 - val_loss: 0.3653 - val_accuracy: 0.8422
# Epoch 12/30
# 879/879 [==============================] - 4s 5ms/step - loss: 0.2580 - accuracy: 0.8898 - val_loss: 0.3722 - val_accuracy: 0.8445
# Epoch 13/30
# 879/879 [==============================] - 4s 5ms/step - loss: 0.2485 - accuracy: 0.8947 - val_loss: 0.3898 - val_accuracy: 0.8384
# Epoch 14/30
# 879/879 [==============================] - 4s 5ms/step - loss: 0.2402 - accuracy: 0.9002 - val_loss: 0.3977 - val_accuracy: 0.8386
# Epoch 15/30
# 879/879 [==============================] - 4s 5ms/step - loss: 0.2361 - accuracy: 0.9022 - val_loss: 0.3810 - val_accuracy: 0.8373
# Epoch 16/30
# 879/879 [==============================] - 4s 5ms/step - loss: 0.2251 - accuracy: 0.9056 - val_loss: 0.3883 - val_accuracy: 0.8334
# Epoch 17/30
# 879/879 [==============================] - 4s 5ms/step - loss: 0.2219 - accuracy: 0.9094 - val_loss: 0.4560 - val_accuracy: 0.8221
# Epoch 18/30
# 879/879 [==============================] - 4s 5ms/step - loss: 0.2144 - accuracy: 0.9118 - val_loss: 0.3987 - val_accuracy: 0.8367
# Epoch 19/30
# 879/879 [==============================] - 4s 5ms/step - loss: 0.2092 - accuracy: 0.9131 - val_loss: 0.4156 - val_accuracy: 0.8341
# Epoch 20/30
# 879/879 [==============================] - 4s 5ms/step - loss: 0.2055 - accuracy: 0.9152 - val_loss: 0.4368 - val_accuracy: 0.8366
# Epoch 21/30
# 879/879 [==============================] - 4s 5ms/step - loss: 0.2050 - accuracy: 0.9159 - val_loss: 0.4103 - val_accuracy: 0.8365
# Epoch 22/30
# 879/879 [==============================] - 4s 5ms/step - loss: 0.1998 - accuracy: 0.9187 - val_loss: 0.4294 - val_accuracy: 0.8370
# Epoch 23/30
# 879/879 [==============================] - 4s 5ms/step - loss: 0.1979 - accuracy: 0.9196 - val_loss: 0.4253 - val_accuracy: 0.8335
# Epoch 24/30
# 879/879 [==============================] - 4s 5ms/step - loss: 0.1883 - accuracy: 0.9252 - val_loss: 0.4287 - val_accuracy: 0.8366
# Epoch 25/30
# 879/879 [==============================] - 4s 5ms/step - loss: 0.1859 - accuracy: 0.9249 - val_loss: 0.4539 - val_accuracy: 0.8270
# Epoch 26/30
# 879/879 [==============================] - 4s 5ms/step - loss: 0.1798 - accuracy: 0.9269 - val_loss: 0.4407 - val_accuracy: 0.8325
# Epoch 27/30
# 879/879 [==============================] - 4s 5ms/step - loss: 0.1824 - accuracy: 0.9267 - val_loss: 0.4460 - val_accuracy: 0.8343
# Epoch 28/30
# 879/879 [==============================] - 4s 5ms/step - loss: 0.1735 - accuracy: 0.9291 - val_loss: 0.4715 - val_accuracy: 0.8366
# Epoch 29/30
# 879/879 [==============================] - 4s 5ms/step - loss: 0.1730 - accuracy: 0.9297 - val_loss: 0.4750 - val_accuracy: 0.8332
# Epoch 30/30
# 879/879 [==============================] - 4s 5ms/step - loss: 0.1668 - accuracy: 0.9339 - val_loss: 0.4724 - val_accuracy: 0.8310

# %%
model_embed.evaluate(X_test,y_test)
# Out:
# 391/391 [==============================] - 1s 1ms/step - loss: 0.4440 - accuracy: 0.8421
# [0.4440276622772217, 0.8420799970626831]

# %%
(X_, y_), (X_test, y_test) = reuters.load_data()
X = np.append(X_, X_test, 0)
y = np.append(y_, y_test)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2110848/2110848 [==============================] - 0s 0us/step

# %%
word_index = imdb.get_word_index()
index_word = {v:k for k,v in word_index.items()}

# %%
for idx1, ind_word in enumerate(X):
    for idx2, val in enumerate(ind_word):
        X[idx1][idx2] = index_word.get(X[idx1][idx2])

# %%
word_list = []
for words in X:
    word_list.extend(words)

# %%
word_freq = Counter(word_list).most_common(1000)

# %%
word_to_index = {v:k for k, (v,_) in enumerate(word_freq,1)}

# %%
index_to_word = {v:k for k,v in word_to_index.items()}

# %%
for idx1, ind_word in enumerate(X):
    for idx2, val in enumerate(ind_word):
        if word_to_index.get(X[idx1][idx2]) != None:
            X[idx1][idx2] = word_to_index.get(X[idx1][idx2])
        else:
            X[idx1][idx2] = 0

# %%
X = pd.Series(X).apply(lambda x:np.array(x)[np.array(x)>0]).values

# %%
X = pad_sequences(X,200)

# %%
y = to_categorical(y)

# %%
X_, X_test, y_, y_test = train_test_split(X,y)

# %%
X_train, X_validation, y_train, y_validation = train_test_split(X_, y_)

# %%
model_reuter = Sequential(
[
    Embedding(1001, 20, input_length=200),
    Conv1D(40,10,activation='relu'),
    MaxPooling1D(5),
    Flatten(),
    Dense(256,activation='relu'),
    BatchNormalization(),
    Dense(128,activation='relu'),
    BatchNormalization(),
    Dense(46,activation='softmax')
])

# %%
model_reuter.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_13 (Embedding)    (None, 200, 8)            8008
#
#  conv1d_3 (Conv1D)           (None, 198, 20)           500
#
#  max_pooling1d_3 (MaxPoolin  (None, 99, 20)            0
#  g1D)
#
#  flatten_11 (Flatten)        (None, 1980)              0
#
#  dense_38 (Dense)            (None, 256)               507136
#
#  batch_normalization_24 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  dense_39 (Dense)            (None, 128)               32896
#
#  batch_normalization_25 (Ba  (None, 128)               512
#  tchNormalization)
#
#  dense_40 (Dense)            (None, 64)                8256
#
#  batch_normalization_26 (Ba  (None, 64)                256
#  tchNormalization)
#
#  dense_41 (Dense)            (None, 46)                2990
#
# =================================================================
# Total params: 561578 (2.14 MB)
# Trainable params: 560682 (2.14 MB)
# Non-trainable params: 896 (3.50 KB)
# _________________________________________________________________

# %%
model_reuter.compile(optimizer='adam',loss='binary_crossentropy',metrics='accuracy')

# %%
model_reuter.fit(X_train, y_train, epochs=30, validation_data=(X_validation, y_validation))
# Out:
# Epoch 1/30
# 198/198 [==============================] - 3s 7ms/step - loss: 0.3682 - accuracy: 0.4100 - val_loss: 0.0865 - val_accuracy: 0.3424
# Epoch 2/30
# 198/198 [==============================] - 1s 6ms/step - loss: 0.0588 - accuracy: 0.5926 - val_loss: 0.0602 - val_accuracy: 0.4402
# Epoch 3/30
# 198/198 [==============================] - 1s 6ms/step - loss: 0.0401 - accuracy: 0.7097 - val_loss: 0.0480 - val_accuracy: 0.6686
# Epoch 4/30
# 198/198 [==============================] - 1s 6ms/step - loss: 0.0295 - accuracy: 0.7976 - val_loss: 0.0460 - val_accuracy: 0.6671
# Epoch 5/30
# 198/198 [==============================] - 1s 6ms/step - loss: 0.0219 - accuracy: 0.8614 - val_loss: 0.0482 - val_accuracy: 0.6847
# Epoch 6/30
# 198/198 [==============================] - 1s 6ms/step - loss: 0.0166 - accuracy: 0.9075 - val_loss: 0.0516 - val_accuracy: 0.6866
# Epoch 7/30
# 198/198 [==============================] - 1s 6ms/step - loss: 0.0132 - accuracy: 0.9341 - val_loss: 0.0530 - val_accuracy: 0.6785
# Epoch 8/30
# 198/198 [==============================] - 1s 6ms/step - loss: 0.0107 - accuracy: 0.9490 - val_loss: 0.0490 - val_accuracy: 0.7018
# Epoch 9/30
# 198/198 [==============================] - 1s 6ms/step - loss: 0.0088 - accuracy: 0.9569 - val_loss: 0.0558 - val_accuracy: 0.6762
# Epoch 10/30
# 198/198 [==============================] - 1s 6ms/step - loss: 0.0075 - accuracy: 0.9596 - val_loss: 0.0513 - val_accuracy: 0.7023
# Epoch 11/30
# 198/198 [==============================] - 1s 6ms/step - loss: 0.0066 - accuracy: 0.9633 - val_loss: 0.0533 - val_accuracy: 0.6833
# Epoch 12/30
# 198/198 [==============================] - 1s 6ms/step - loss: 0.0060 - accuracy: 0.9625 - val_loss: 0.0565 - val_accuracy: 0.6880
# Epoch 13/30
# 198/198 [==============================] - 1s 6ms/step - loss: 0.0054 - accuracy: 0.9653 - val_loss: 0.0602 - val_accuracy: 0.6871
# Epoch 14/30
# 198/198 [==============================] - 1s 6ms/step - loss: 0.0050 - accuracy: 0.9648 - val_loss: 0.0585 - val_accuracy: 0.6914
# Epoch 15/30
# 198/198 [==============================] - 1s 6ms/step - loss: 0.0047 - accuracy: 0.9653 - val_loss: 0.0622 - val_accuracy: 0.6914
# Epoch 16/30
# 198/198 [==============================] - 1s 6ms/step - loss: 0.0044 - accuracy: 0.9667 - val_loss: 0.0597 - val_accuracy: 0.7056
# Epoch 17/30
# 198/198 [==============================] - 1s 6ms/step - loss: 0.0044 - accuracy: 0.9667 - val_loss: 0.0589 - val_accuracy: 0.6994
# Epoch 18/30
# 198/198 [==============================] - 1s 6ms/step - loss: 0.0041 - accuracy: 0.9664 - val_loss: 0.0654 - val_accuracy: 0.6790
# Epoch 19/30
# 198/198 [==============================] - 1s 6ms/step - loss: 0.0042 - accuracy: 0.9666 - val_loss: 0.0643 - val_accuracy: 0.6947
# Epoch 20/30
# 198/198 [==============================] - 1s 6ms/step - loss: 0.0041 - accuracy: 0.9671 - val_loss: 0.0680 - val_accuracy: 0.6890
# Epoch 21/30
# 198/198 [==============================] - 1s 6ms/step - loss: 0.0041 - accuracy: 0.9655 - val_loss: 0.0687 - val_accuracy: 0.6852
# Epoch 22/30
# 198/198 [==============================] - 1s 6ms/step - loss: 0.0038 - accuracy: 0.9671 - val_loss: 0.0708 - val_accuracy: 0.7004
# Epoch 23/30
# 198/198 [==============================] - 1s 6ms/step - loss: 0.0037 - accuracy: 0.9698 - val_loss: 0.0674 - val_accuracy: 0.6895
# Epoch 24/30
# 198/198 [==============================] - 1s 6ms/step - loss: 0.0043 - accuracy: 0.9642 - val_loss: 0.0739 - val_accuracy: 0.6814
# Epoch 25/30
# 198/198 [==============================] - 1s 6ms/step - loss: 0.0042 - accuracy: 0.9655 - val_loss: 0.0714 - val_accuracy: 0.6918
# Epoch 26/30
# 198/198 [==============================] - 1s 6ms/step - loss: 0.0041 - accuracy: 0.9642 - val_loss: 0.0734 - val_accuracy: 0.6809
# Epoch 27/30
# 198/198 [==============================] - 1s 6ms/step - loss: 0.0041 - accuracy: 0.9655 - val_loss: 0.0706 - val_accuracy: 0.6847
# Epoch 28/30
# 198/198 [==============================] - 1s 6ms/step - loss: 0.0037 - accuracy: 0.9699 - val_loss: 0.0725 - val_accuracy: 0.6999
# Epoch 29/30
# 198/198 [==============================] - 1s 6ms/step - loss: 0.0035 - accuracy: 0.9674 - val_loss: 0.0710 - val_accuracy: 0.6966
# Epoch 30/30
# 198/198 [==============================] - 1s 6ms/step - loss: 0.0033 - accuracy: 0.9683 - val_loss: 0.0735 - val_accuracy: 0.6923

# %%
model_reuter.evaluate(X_test, y_test)
# Out:
# 88/88 [==============================] - 0s 2ms/step - loss: 0.0744 - accuracy: 0.6915
# [0.07436802983283997, 0.691485583782196]
