# %%
import numpy as np

from sklearn.datasets import load_breast_cancer
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Flatten

# %%
def linear(x):
    return x

def relu(x):
    return np.where(x > 0, x, 0)

def sigmoid(x):
    return 1/(1+np.exp(-x))

def tanh(x):
    return (1-np.exp(x))/(1+np.exp(x))

def softmax(x):
    x -= np.max(x,1).reshape(x.shape[0],-1)
    return np.exp(x)/np.sum(np.exp(x),1).reshape(x.shape[0],-1)

def rmse(y_hat, y):
    return np.mean(np.square(y_hat - y))

def binary_crossentropy(y_hat, y):
    epsilon = 1e-7
    return np.mean((1-y)*np.log(1-y_hat+epsilon) + y*np.log(y_hat+epsilon))

def categorical_crossentropy(y_hat, y):
    epsilon = 1e-7
    return -np.mean(y*np.log(y_hat+epsilon))

def make_onehot(x):
    result = np.zeros((x.size, np.max(x)+1))
    for idx, val in enumerate(x):
        result[idx,val] = 1
    return result

# %%
x = np.array([[1,2,1000],[1000,5,6]])

# %%
np.sum(softmax(x),1), softmax(x)
# Out:
# (array([1., 1.]),
#  array([[0., 0., 1.],
#         [1., 0., 0.]]))

# %%
class SequentialModel:
    def __init__(self,x,y,output_shape, activation='linear'):
        self.activation_dic = {
            'linear' : linear,
            'sigmoid' : sigmoid,
            'relu' : relu,
            'softmax' : softmax
        }
        self.loss_func_dic = {
            'rmse' : rmse,
            'binary_crossentropy' : binary_crossentropy,
            'categorical_crossentropy' : categorical_crossentropy
        }
        self.x = x
        self.y = y
        self.activation = [activation]
        self.W = [[np.random.randn(self.x.shape[1], output_shape), 
                 np.zeros(output_shape)]]
        self.dW = [[np.zeros((self.x.shape[1], output_shape)),
                  np.zeros(output_shape)]
]
    
    def add(self,output,activation='linear'):
        self.input = self.W[-1][0].shape[1]
        self.W.append([np.random.randn(self.input,output),np.zeros(output)])
        self.dW.append([np.zeros((self.input,output)),np.zeros(output)])
        self.activation.append(activation)
        
    def predict(self):
        self.y_hat = self.x.copy()
        for i in range(len(self.W)):
            self.y_hat = np.dot(self.y_hat, self.W[i][0]) + self.W[i][1]
            self.y_hat = self.activation_dic[self.activation[i]](self.y_hat)
        return self.y_hat
    
    def compile(self, loss):
        self.loss_func = self.loss_func_dic[loss]
        
    def summary(self):
        print("------------------------------")
        print("Output Shape           Param #")
        print("==============================")
        total_params = 0
        for idx, W in enumerate(self.W):
            tmp_length = 38- int(6 + len(str(W[0].shape[1])))
            print(f'(None, {W[0].shape[1]})' f'{W[0].shape[0]*W[0].shape[1] + W[0].shape[1]:^{tmp_length}}\n')
            total_params += W[0].shape[0]*W[0].shape[1] + W[0].shape[1]
        print("==============================")
        print(f"total params: {total_params}")
        
    def loss(self):
        s = time()
        y_hat = self.predict()
        y = self.y
        self.loss_val = self.loss_func(y_hat, y)
        e = time()
        self.predict_elapse = (e - s)
        self.forword_elapse = self.predict_elapse
        return self.loss_val
    
    def gradient(self):
        for layer in range(len(self.W)):
            h = 1e-5 
            weight = 0
            bias = 1
            rows = range(self.W[layer][weight].shape[0])
            cols = range(self.W[layer][weight].shape[1])
            print(f'{rows[-1]} * {cols[-1]} 번 돌아야합니다.')
            for row in rows:
                for col in cols:
                    print(f'{layer+1}-{str(row+1)}-{str(col+1)}')
                    fx = self.loss()
                    self.W[layer][weight][row,col] += h
                    fxh = self.loss()
                    self.dW[layer][weight][row,col] = (fxh-fx)/h
                    self.W[layer][weight][row,col] -= h
            for b_idx in range(self.W[layer][bias].size):
                fx = self.loss()
                self.W[layer][bias][b_idx] += h
                fxh = self.loss()
                self.dW[layer][bias][b_idx] = (fxh-fx)/h
                self.W[layer][bias][b_idx] -= h    
    
    def descent_gradient(self,lr=1e-3):
        self.lr = lr
        weight = 0
        bias = 1
        layers = range(len(self.W))
        self.gradient()
        for layer in layers:
            self.W[layer][weight] -= self.dW[layer][weight]*self.lr
            self.W[layer][bias] -= self.dW[layer][bias]*self.lr
        
    def fit(self,lr,epochs=100):
        for epoch in range(epochs):
            print(f'{epoch+1}번째 진행 중..')
            self.descent_gradient(lr)

# %%
y = np.random.randint(0,4,100)
y_one = make_onehot(y)
model = SequentialModel(np.random.randn(100,10),y_one,100)
model.add(40, activation='relu')
model.add(4, activation='softmax')

# %%
model.compile('categorical_crossentropy')

# %%
model.summary()
# Out:
# ------------------------------
# Output Shape           Param #
# ==============================
# (None, 100)            1100
#
# (None, 40)             4040
#
# (None, 4)              164
#
# ==============================
# total params: 5304

# %%
model.fit(epochs=20, lr=1e-3)

# %%
model.loss()
# Out:
# 2.550166278369687

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
X_train_ = X_train.reshape(-1,28*28)
X_test_ = X_test.reshape(-1,28*28)
y_train_ = to_categorical(y_train)
y_test_ = to_categorical(y_test)

# %%
tf_model = Sequential()

input_layer = Dense(256,activation='relu',input_shape=(784,))
layer1 = Dense(128, activation='relu')
output_layer = Dense(10,activation='softmax')

tf_model.add(input_layer)
tf_model.add(layer1)
tf_model.add(output_layer)

# %%
tf_model.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
tf_model.fit(X_train_, y_train_,epochs=10)
# Out:
# Epoch 1/10
# 1748/1875 [==========================>...] - ETA: 0s - loss: 2.0948 - accuracy: 0.8827
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[510], line 1
# ----> 1 tf_model.fit(X_train_, y_train_,epochs=10)
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\Lib\site-packages\keras\src\engine\training.py:1798, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1796 callbacks.on_epoch_begin(epoch)
#    1797 with data_handler.catch_stop_iteration():
# -> 1798     for step in data_handler.steps():
#    1799         with tf.profiler.experimental.Trace(
#    1800             "train",
#    1801             epoch_num=epoch,
#    (...)
#    1804             _r=1,
#    1805         ):
#    1806             callbacks.on_train_batch_begin(step)
#
# File ~\anaconda3\Lib\site-packages\keras\src\engine\data_adapter.py:1411, in DataHandler.steps(self)
#    1409 if self._insufficient_data:  # Set by `catch_stop_iteration`.
#    1410     break
# -> 1411 original_spe = self._steps_per_execution.numpy().item()
#    1412 can_run_full_execution = (
#    1413     original_spe == 1
#    1414     or self._inferred_steps is None
#    1415     or self._inferred_steps - self._current_step >= original_spe
#    1416 )
#    1418 if can_run_full_execution:
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:689, in BaseResourceVariable.numpy(self)
#     687 def numpy(self):
#     688   if context.executing_eagerly():
# --> 689     return self.read_value().numpy()
#     690   raise NotImplementedError(
#     691       "numpy() is only available when eager execution is enabled.")
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:839, in BaseResourceVariable.read_value(self)
#     830 """Constructs an op which reads the value of this variable.
#     831
#     832 Should be used when there are multiple reads, or when it is desirable to
#    (...)
#     836   The value of the variable.
#     837 """
#     838 with ops.name_scope("Read"):
# --> 839   value = self._read_variable_op()
#     840 # Return an identity so it can get placed on whatever device the context
#     841 # specifies instead of the device where the variable is.
#     842 return array_ops.identity(value)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:818, in BaseResourceVariable._read_variable_op(self, no_copy)
#     816       result = read_and_set_handle(no_copy)
#     817 else:
# --> 818   result = read_and_set_handle(no_copy)
#     820 if not context.executing_eagerly():
#     821   # Note that if a control flow context is active the input of the read op
#     822   # might not actually be the handle. This line bypasses it.
#     823   record.record_operation(
#     824       "ReadVariableOp", [result], [self.handle],
#     825       backward_function=lambda x: [x],
#     826       forward_function=lambda x: [x])
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:808, in BaseResourceVariable._read_variable_op.<locals>.read_and_set_handle(no_copy)
#     806 if no_copy and forward_compat.forward_compatible(2022, 5, 3):
#     807   gen_resource_variable_ops.disable_copy_on_read(self.handle)
# --> 808 result = gen_resource_variable_ops.read_variable_op(
#     809     self.handle, self._dtype)
#     810 _maybe_set_handle_data(self._dtype, self.handle, result)
#     811 return result
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\ops\gen_resource_variable_ops.py:535, in read_variable_op(resource, dtype, name)
#     533 if tld.is_eager:
#     534   try:
# --> 535     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     536       _ctx, "ReadVariableOp", name, resource, "dtype", dtype)
#     537     return _result
#     538   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
tf_model.evaluate(X_test_,y_test_)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.6561 - accuracy: 0.9153
# [0.6561394929885864, 0.9153000116348267]

# %%
tf_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 256)               200960
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  dense_5 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 235146 (918.54 KB)
# Trainable params: 235146 (918.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
our_model = SequentialModel(X_train_, y_train_, 256, activation='relu')

# %%
our_model.add(128, activation='relu')
our_model.add(10, activation='softmax')
our_model.summary()
# Out:
# ------------------------------
# Output Shape           Param #
# ==============================
# (None, 256)           200960
#
# (None, 128)            32896
#
# (None, 10)             1290
#
# ==============================
# total params: 235146

# %%
our_model.compile(loss='categorical_crossentropy')

# %%
our_model.fit(lr=1e-3, epochs=2)
# Out:
# 1번째 진행 중..
# 783 * 255 번 돌아야합니다.
# 1-1-1
# 1-1-2
# 1-1-3
# 1-1-4
# 1-1-5
# 1-1-6
# 1-1-7
# 1-1-8
# 1-1-9
# 1-1-10
# 1-1-11
# 1-1-12
# 1-1-13
# 1-1-14
# 1-1-15
# 1-1-16
# 1-1-17
# 1-1-18
# 1-1-19
# 1-1-20
# 1-1-21
# 1-1-22
# 1-1-23
# 1-1-24
# 1-1-25
# 1-1-26
# 1-1-27
# 1-1-28
# 1-1-29
# 1-1-30
# 1-1-31
# 1-1-32
# 1-1-33
# 1-1-34
# 1-1-35
# 1-1-36
# 1-1-37
# 1-1-38
# 1-1-39
# 1-1-40
# 1-1-41
# 1-1-42
# 1-1-43
# 1-1-44
# 1-1-45
# 1-1-46
# 1-1-47
# 1-1-48
# 1-1-49
# 1-1-50
# 1-1-51
# 1-1-52
# 1-1-53
# 1-1-54
# 1-1-55
# 1-1-56
# 1-1-57
# 1-1-58
# 1-1-59
# 1-1-60
# 1-1-61
# 1-1-62
# 1-1-63
# 1-1-64
# 1-1-65
# 1-1-66
# 1-1-67
# 1-1-68
# 1-1-69
# 1-1-70
# 1-1-71
# 1-1-72
# 1-1-73
# 1-1-74
# 1-1-75
# 1-1-76
# 1-1-77
# 1-1-78
# 1-1-79
# 1-1-80
# 1-1-81
# 1-1-82
# 1-1-83
# 1-1-84
# 1-1-85
# 1-1-86
# 1-1-87
# 1-1-88
# 1-1-89
# 1-1-90
# 1-1-91
# 1-1-92
# 1-1-93
# 1-1-94
# 1-1-95
# 1-1-96
# 1-1-97
# 1-1-98
# 1-1-99
# 1-1-100
# 1-1-101
# 1-1-102
# 1-1-103
# 1-1-104
# 1-1-105
# 1-1-106
# 1-1-107
# 1-1-108
# 1-1-109
# 1-1-110
# 1-1-111
# 1-1-112
# 1-1-113
# 1-1-114
# 1-1-115
# 1-1-116
# 1-1-117
# 1-1-118
# 1-1-119
# 1-1-120
# 1-1-121
# 1-1-122
# 1-1-123
# 1-1-124
# 1-1-125
# 1-1-126
# 1-1-127
# 1-1-128
# 1-1-129
# 1-1-130
# 1-1-131
# 1-1-132
# 1-1-133
# 1-1-134
# 1-1-135
# 1-1-136
# 1-1-137
# 1-1-138
# 1-1-139
# 1-1-140
# 1-1-141
# 1-1-142
# 1-1-143
# 1-1-144
# 1-1-145
# 1-1-146
# 1-1-147
# 1-1-148
# 1-1-149
# 1-1-150
# 1-1-151
# 1-1-152
# 1-1-153
# 1-1-154
# 1-1-155
# 1-1-156
# 1-1-157
# 1-1-158
# 1-1-159
# 1-1-160
# 1-1-161
# 1-1-162
# 1-1-163
# 1-1-164
# 1-1-165
# 1-1-166
# 1-1-167
# 1-1-168
# 1-1-169
# 1-1-170
# 1-1-171
# 1-1-172
# 1-1-173
# 1-1-174
# 1-1-175
# 1-1-176
# 1-1-177
# 1-1-178
# 1-1-179
# 1-1-180
# 1-1-181
# 1-1-182
# 1-1-183
# 1-1-184
# 1-1-185
# 1-1-186
# 1-1-187
# 1-1-188
# 1-1-189
# 1-1-190
# 1-1-191
# 1-1-192
# 1-1-193
# 1-1-194
# 1-1-195
# 1-1-196
# 1-1-197
# 1-1-198
# 1-1-199
# 1-1-200
# 1-1-201
# 1-1-202
# 1-1-203
# 1-1-204
# 1-1-205
# 1-1-206
# 1-1-207
# 1-1-208
# 1-1-209
# 1-1-210
# 1-1-211
# 1-1-212
# 1-1-213
# 1-1-214
# 1-1-215
# 1-1-216
# 1-1-217
# 1-1-218
# 1-1-219
# 1-1-220
# 1-1-221
# 1-1-222
# 1-1-223
# 1-1-224
# 1-1-225
# 1-1-226
# 1-1-227
# 1-1-228
# 1-1-229
# 1-1-230
# 1-1-231
# 1-1-232
# 1-1-233
# 1-1-234
# 1-1-235
# 1-1-236
# 1-1-237
# 1-1-238
# 1-1-239
# 1-1-240
# 1-1-241
# 1-1-242
# 1-1-243
# 1-1-244
# 1-1-245
# 1-1-246
# 1-1-247
# 1-1-248
# 1-1-249
# 1-1-250
# 1-1-251
# 1-1-252
# 1-1-253
# 1-1-254
# 1-1-255
# 1-1-256
# 1-2-1
# 1-2-2
# 1-2-3
# 1-2-4
# 1-2-5
# 1-2-6
# 1-2-7
# 1-2-8
# 1-2-9
# 1-2-10
# 1-2-11
# 1-2-12
# 1-2-13
# 1-2-14
# 1-2-15
# 1-2-16
# 1-2-17
# 1-2-18
# 1-2-19
# 1-2-20
# 1-2-21
# 1-2-22
# 1-2-23
# 1-2-24
# 1-2-25
# 1-2-26
# 1-2-27
# 1-2-28
# 1-2-29
# 1-2-30
# 1-2-31
# 1-2-32
# 1-2-33
# 1-2-34
# 1-2-35
# 1-2-36
# 1-2-37
# 1-2-38
# 1-2-39
# 1-2-40
# 1-2-41
# 1-2-42
# 1-2-43
# 1-2-44
# 1-2-45
# 1-2-46
# 1-2-47
# 1-2-48
# 1-2-49
# 1-2-50
# 1-2-51
# 1-2-52
# 1-2-53
# 1-2-54
# 1-2-55
# 1-2-56
# 1-2-57
# 1-2-58
# 1-2-59
# 1-2-60
# 1-2-61
# 1-2-62
# 1-2-63
# 1-2-64
# 1-2-65
# 1-2-66
# 1-2-67
# 1-2-68
# 1-2-69
# 1-2-70
# 1-2-71
# 1-2-72
# 1-2-73
# 1-2-74
# 1-2-75
# 1-2-76
# 1-2-77
# 1-2-78
# 1-2-79
# 1-2-80
# 1-2-81
# 1-2-82
# 1-2-83
# 1-2-84
# 1-2-85
# 1-2-86
# 1-2-87
# 1-2-88
# 1-2-89
# 1-2-90
# 1-2-91
# 1-2-92
# 1-2-93
# 1-2-94
# 1-2-95
# 1-2-96
# 1-2-97
# 1-2-98
# 1-2-99
# 1-2-100
# 1-2-101
# 1-2-102
# 1-2-103
# 1-2-104
# 1-2-105
# 1-2-106
# 1-2-107
# 1-2-108
# 1-2-109
# 1-2-110
# 1-2-111
# 1-2-112
# 1-2-113
# 1-2-114
# 1-2-115
# 1-2-116
# 1-2-117
# 1-2-118
# 1-2-119
# 1-2-120
# 1-2-121
# 1-2-122
# 1-2-123
# 1-2-124
# 1-2-125
# 1-2-126
# 1-2-127
# 1-2-128
# 1-2-129
# 1-2-130
# 1-2-131
# 1-2-132
# 1-2-133
# 1-2-134
# 1-2-135
# 1-2-136
# 1-2-137
# 1-2-138
# 1-2-139
# 1-2-140
# 1-2-141
# 1-2-142
# 1-2-143
# 1-2-144
# 1-2-145
# 1-2-146
# 1-2-147
# 1-2-148
# 1-2-149
# 1-2-150
# 1-2-151
# 1-2-152
# 1-2-153
# 1-2-154
# 1-2-155
# 1-2-156
# 1-2-157
# 1-2-158
# 1-2-159
# 1-2-160
# 1-2-161
# 1-2-162
# 1-2-163
# 1-2-164
# 1-2-165
# 1-2-166
# 1-2-167
# 1-2-168
# 1-2-169
# 1-2-170
# 1-2-171
# 1-2-172
# 1-2-173
# 1-2-174
# 1-2-175
# 1-2-176
# 1-2-177
# 1-2-178
# 1-2-179
# 1-2-180
# 1-2-181
# 1-2-182
# 1-2-183
# 1-2-184
# 1-2-185
# 1-2-186
# 1-2-187
# 1-2-188
# 1-2-189
# 1-2-190
# 1-2-191
# 1-2-192
# 1-2-193
# 1-2-194
# 1-2-195
# 1-2-196
# 1-2-197
# 1-2-198
# 1-2-199
# 1-2-200
# 1-2-201
# 1-2-202
# 1-2-203
# 1-2-204
# 1-2-205
# 1-2-206
# 1-2-207
# 1-2-208
# 1-2-209
# 1-2-210
# 1-2-211
# 1-2-212
# 1-2-213
# 1-2-214
# 1-2-215
# 1-2-216
# 1-2-217
# 1-2-218
# 1-2-219
# 1-2-220
# 1-2-221
# 1-2-222
# 1-2-223
# 1-2-224
# 1-2-225
# 1-2-226
# 1-2-227
# 1-2-228
# 1-2-229
# 1-2-230
# 1-2-231
# 1-2-232
# 1-2-233
# 1-2-234
# 1-2-235
# 1-2-236
# 1-2-237
# 1-2-238
# 1-2-239
# 1-2-240
# 1-2-241
# 1-2-242
# 1-2-243
# 1-2-244
# 1-2-245
# 1-2-246
# 1-2-247
# 1-2-248
# 1-2-249
# 1-2-250
# 1-2-251
# 1-2-252
# 1-2-253
# 1-2-254
# 1-2-255
# 1-2-256
# 1-3-1
# 1-3-2
# 1-3-3
# 1-3-4
# 1-3-5
# 1-3-6
# 1-3-7
# 1-3-8
# 1-3-9
# 1-3-10
# 1-3-11
# 1-3-12
# 1-3-13
# 1-3-14
# 1-3-15
# 1-3-16
# 1-3-17
# 1-3-18
# 1-3-19
# 1-3-20
# 1-3-21
# 1-3-22
# 1-3-23
# 1-3-24
# 1-3-25
# 1-3-26
# 1-3-27
# 1-3-28
# 1-3-29
# 1-3-30
# 1-3-31
# 1-3-32
# 1-3-33
# 1-3-34
# 1-3-35
# 1-3-36
# 1-3-37
# 1-3-38
# 1-3-39
# 1-3-40
# 1-3-41
# 1-3-42
# 1-3-43
# 1-3-44
# 1-3-45
# 1-3-46
# 1-3-47
# 1-3-48
# 1-3-49
# 1-3-50
# 1-3-51
# 1-3-52
# 1-3-53
# 1-3-54
# 1-3-55
# 1-3-56
# 1-3-57
# 1-3-58
# 1-3-59
# 1-3-60
# 1-3-61
# 1-3-62
# 1-3-63
# 1-3-64
# 1-3-65
# 1-3-66
# 1-3-67
# 1-3-68
# 1-3-69
# 1-3-70
# 1-3-71
# 1-3-72
# 1-3-73
# 1-3-74
# 1-3-75
# 1-3-76
# 1-3-77
# 1-3-78
# 1-3-79
# 1-3-80
# 1-3-81
# 1-3-82
# 1-3-83
# 1-3-84
# 1-3-85
# 1-3-86
# 1-3-87
# 1-3-88
# 1-3-89
# 1-3-90
# 1-3-91
# 1-3-92
# 1-3-93
# 1-3-94
# 1-3-95
# 1-3-96
# 1-3-97
# 1-3-98
# 1-3-99
# 1-3-100
# 1-3-101
# 1-3-102
# 1-3-103
# 1-3-104
# 1-3-105
# 1-3-106
# 1-3-107
# 1-3-108
# 1-3-109
# 1-3-110
# 1-3-111
# 1-3-112
# 1-3-113
# 1-3-114
# 1-3-115
# 1-3-116
# 1-3-117
# 1-3-118
# 1-3-119
# 1-3-120
# 1-3-121
# 1-3-122
# 1-3-123
# 1-3-124
# 1-3-125
# 1-3-126
# 1-3-127
# 1-3-128
# 1-3-129
# 1-3-130
# 1-3-131
# 1-3-132
# 1-3-133
# 1-3-134
# 1-3-135
# 1-3-136
# 1-3-137
# 1-3-138
# 1-3-139
# 1-3-140
# 1-3-141
# 1-3-142
# 1-3-143
# 1-3-144
# 1-3-145
# 1-3-146
# 1-3-147
# 1-3-148
# 1-3-149
# 1-3-150
# 1-3-151
# 1-3-152
# 1-3-153
# 1-3-154
# 1-3-155
# 1-3-156
# 1-3-157
# 1-3-158
# 1-3-159
# 1-3-160
# 1-3-161
# 1-3-162
# 1-3-163
# 1-3-164
# 1-3-165
# 1-3-166
# 1-3-167
# 1-3-168
# 1-3-169
# 1-3-170
# 1-3-171
# 1-3-172
# 1-3-173
# 1-3-174
# 1-3-175
# 1-3-176
# 1-3-177
# 1-3-178
# 1-3-179
# 1-3-180
# 1-3-181
# 1-3-182
# 1-3-183
# 1-3-184
# 1-3-185
# 1-3-186
# 1-3-187
# 1-3-188
# 1-3-189
# 1-3-190
# 1-3-191
# 1-3-192
# 1-3-193
# 1-3-194
# 1-3-195
# 1-3-196
# 1-3-197
# 1-3-198
# 1-3-199
# 1-3-200
# 1-3-201
# 1-3-202
# 1-3-203
# 1-3-204
# 1-3-205
# 1-3-206
# 1-3-207
# 1-3-208
# 1-3-209
# 1-3-210
# 1-3-211
# 1-3-212
# 1-3-213
# 1-3-214
# 1-3-215
# 1-3-216
# 1-3-217
# 1-3-218
# 1-3-219
# 1-3-220
# 1-3-221
# 1-3-222
# 1-3-223
# 1-3-224
# 1-3-225
# 1-3-226
# 1-3-227
# 1-3-228
# 1-3-229
# 1-3-230
# 1-3-231
# 1-3-232
# 1-3-233
# 1-3-234
# 1-3-235
# 1-3-236
# 1-3-237
# 1-3-238
# 1-3-239
# 1-3-240
# 1-3-241
# 1-3-242
# 1-3-243
# 1-3-244
# 1-3-245
# 1-3-246
# 1-3-247
# 1-3-248
# 1-3-249
# 1-3-250
# 1-3-251
# 1-3-252
# 1-3-253
# 1-3-254
# 1-3-255
# 1-3-256
# 1-4-1
# 1-4-2
# 1-4-3
# 1-4-4
# 1-4-5
# 1-4-6
# 1-4-7
# 1-4-8
# 1-4-9
# 1-4-10
# 1-4-11
# 1-4-12
# 1-4-13
# 1-4-14
# 1-4-15
# 1-4-16
# 1-4-17
# 1-4-18
# 1-4-19
# 1-4-20
# 1-4-21
# 1-4-22
# 1-4-23
# 1-4-24
# 1-4-25
# 1-4-26
# 1-4-27
# 1-4-28
# 1-4-29
# 1-4-30
# 1-4-31
# 1-4-32
# 1-4-33
# 1-4-34
# 1-4-35
# 1-4-36
# 1-4-37
# 1-4-38
# 1-4-39
# 1-4-40
# 1-4-41
# 1-4-42
# 1-4-43
# 1-4-44
# 1-4-45
# 1-4-46
# 1-4-47
# 1-4-48
# 1-4-49
# 1-4-50
# 1-4-51
# 1-4-52
# 1-4-53
# 1-4-54
# 1-4-55
# 1-4-56
# 1-4-57
# 1-4-58
# 1-4-59
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[588], line 1
# ----> 1 our_model.fit(lr=1e-3, epochs=2)
#
# Cell In[584], line 97, in SequentialModel.fit(self, lr, epochs)
#      95 for epoch in range(epochs):
#      96     print(f'{epoch+1}번째 진행 중..')
# ---> 97     self.descent_gradient(lr)
#
# Cell In[584], line 89, in SequentialModel.descent_gradient(self, lr)
#      87 bias = 1
#      88 layers = range(len(self.W))
# ---> 89 self.gradient()
#      90 for layer in layers:
#      91     self.W[layer][weight] -= self.dW[layer][weight]*self.lr
#
# Cell In[584], line 74, in SequentialModel.gradient(self)
#      72 fx = self.loss()
#      73 self.W[layer][weight][row,col] += h
# ---> 74 fxh = self.loss()
#      75 self.dW[layer][weight][row,col] = (fxh-fx)/h
#      76 self.W[layer][weight][row,col] -= h
#
# Cell In[584], line 53, in SequentialModel.loss(self)
#      51 def loss(self):
#      52     s = time()
# ---> 53     y_hat = self.predict()
#      54     y = self.y
#      55     self.loss_val = self.loss_func(y_hat, y)
#
# Cell In[584], line 33, in SequentialModel.predict(self)
#      31 for i in range(len(self.W)):
#      32     self.y_hat = np.dot(self.y_hat, self.W[i][0]) + self.W[i][1]
# ---> 33     self.y_hat = self.activation_dic[self.activation[i]](self.y_hat)
#      34 return self.y_hat
#
# Cell In[451], line 4, in relu(x)
#       1 def linear(x):
#       2     return x
# ----> 4 def relu(x):
#       5     return np.where(x > 0, x, 0)
#       7 def sigmoid(x):
#
# KeyboardInterrupt:

# %%
from time import time

# %%
np.cumprod(X_train.shape[1:])[-1]
# Out:
# 784

# %%
x = np.random.randn(100000,1000)
w = np.random.randn(1000,1)

# %%
y = np.random.randint(0,1,100000).reshape(-1,1)

# %%
x.shape, w.shape, y.shape
# Out:
# ((100000, 1000), (1000, 1), (100000, 1))

# %%
def loss(x,y):
    epsilon = 1e-7
    y_hat = np.dot(x,w)
    y_hat = sigmoid(y_hat)
    return -np.mean((1-y+epsilon) * np.log(1-y_hat+epsilon) + y * np.log(y_hat+epsilon))

# %%
s = time()
dW = np.zeros_like(w)
h = 1e-5
rows = range(w.shape[0])
cols = range(w.shape[1])
for row in rows:
    for col in cols:
        fx = loss(x,y)
        w[row,col] += h
        fxh = loss(x,y)
        dW[row,col] = (fxh-fx)/h
        w[row,col] -= h
e = time()
elapse = e - s

# %%
dW
# Out:
# array([[ 1.36434259e-03],
#        [-9.07727316e-04],
#        [ 3.82603265e-03],
#        [-3.45556295e-04],
#        [-1.70926384e-05],
#        [-2.15211626e-03],
#        [ 2.66405102e-03],
#        [-4.90124030e-04],
#        [-7.87579779e-05],
#        [-7.62882912e-04],
#        [-8.76554829e-04],
#        [ 6.42317310e-04],
#        [ 3.46949172e-03],
#        [ 2.42092613e-03],
#        [ 1.72141350e-03],
#        [-1.30712738e-03],
#        [-2.73104916e-04],
#        [ 5.11101650e-04],
#        [-4.22171151e-03],
#        [-2.54891903e-03],
#        [ 3.13347384e-03],
#        [-4.13477395e-03],
#        [-2.13599272e-03],
#        [-1.19819878e-03],
#        [-8.13759549e-04],
#        [ 3.69143471e-04],
#        [ 3.48846507e-03],
#        [-9.35560873e-04],
#        [-1.99148360e-03],
#        [-9.75517978e-04],
#        [ 3.31443051e-04],
#        [-1.29016247e-03],
#        [-2.28425456e-03],
#        [-1.60554041e-03],
#        [ 3.28284333e-04],
#        [ 7.55831220e-04],
#        [-1.53474531e-03],
#        [ 3.10340562e-03],
#        [ 2.63532858e-03],
#        [-6.14048563e-03],
#        [-1.68449787e-04],
#        [-2.09997841e-03],
#        [-4.77024376e-04],
#        [ 2.08513695e-03],
#        [ 8.44040571e-04],
#        [-1.10127161e-03],
#        [ 1.17703829e-03],
#        [ 7.56932295e-06],
#        [-6.87056634e-05],
#        [ 1.12201697e-03],
#        [ 6.89732804e-04],
#        [-8.19991808e-04],
#        [ 6.10997919e-04],
#        [ 2.56310075e-03],
#        [ 1.81194979e-03],
#        [-2.34208608e-03],
#        [ 8.87422669e-04],
#        [-1.75720327e-03],
#        [ 1.87162907e-04],
#        [ 2.51245904e-03],
#        [-1.38825689e-03],
#        [-4.13806820e-03],
#        [-5.61623725e-04],
#        [ 1.73617263e-03],
#        [ 1.78224386e-03],
#        [ 1.14899290e-03],
#        [ 1.43389478e-04],
#        [-1.08151630e-03],
#        [ 1.65915051e-03],
#        [-6.44291198e-04],
#        [ 4.46575434e-03],
#        [ 1.03108198e-03],
#        [-2.39164182e-03],
#        [ 2.11494173e-03],
#        [ 6.38790354e-04],
#        [ 1.98455643e-03],
#        [-1.20889547e-03],
#        [ 3.84569976e-04],
#        [ 1.53632644e-03],
#        [-3.97329369e-04],
#        [ 4.01306011e-04],
#        [-1.16114718e-03],
#        [-1.31371340e-03],
#        [ 1.83251583e-03],
#        [-4.85406115e-04],
#        [ 6.37105124e-04],
#        [ 1.36710199e-03],
#        [ 7.55200880e-04],
#        [-7.33218730e-04],
#        [ 3.41159545e-04],
#        [ 9.33578370e-04],
#        [ 3.63416701e-03],
#        [ 1.11714886e-03],
#        [ 1.21293651e-03],
#        [ 3.70102171e-05],
#        [ 5.21921173e-04],
#        [ 1.64143161e-03],
#        [-9.14430487e-04],
#        [-3.97518649e-03],
#        [ 3.34348131e-03],
#        [-3.50424481e-03],
#        [-1.63355107e-04],
#        [-2.76756298e-03],
#        [-2.48996468e-04],
#        [-9.10753162e-04],
#        [ 2.33775230e-03],
#        [-2.17589307e-03],
#        [ 5.45948886e-04],
#        [ 1.56605484e-04],
#        [-4.63743710e-05],
#        [-2.28511965e-04],
#        [-5.57985302e-04],
#        [ 2.19521468e-04],
#        [-3.39886883e-03],
#        [-4.44020998e-04],
#        [ 3.75623888e-04],
#        [ 3.79324900e-03],
#        [ 6.10265793e-04],
#        [-1.30847573e-03],
#        [ 2.73394436e-03],
#        [-9.94153826e-04],
#        [ 2.66467959e-03],
#        [ 1.06989706e-03],
#        [ 2.09479278e-03],
#        [ 1.26368018e-03],
#        [-1.08168488e-03],
#        [-1.40385437e-03],
#        [-4.14183186e-03],
#        [ 1.03023101e-04],
#        [ 2.54779993e-03],
#        [ 7.55903695e-04],
#        [ 9.28330834e-04],
#        [ 2.82790573e-03],
#        [ 7.01392899e-04],
#        [ 1.93861673e-03],
#        [-1.84945987e-03],
#        [ 2.47879637e-03],
#        [ 1.20373826e-03],
#        [-6.39483222e-04],
#        [-1.81727868e-03],
#        [-9.08022901e-04],
#        [ 7.85861154e-04],
#        [-1.44020129e-03],
#        [-3.32641612e-03],
#        [-7.79639020e-04],
#        [ 3.94487234e-03],
#        [ 4.56941773e-04],
#        [-9.15660880e-04],
#        [-9.22789134e-04],
#        [-5.57599744e-04],
#        [ 8.57423554e-04],
#        [ 7.75492293e-04],
#        [-1.94995184e-03],
#        [ 1.09992522e-03],
#        [ 4.42978809e-04],
#        [-9.71709646e-04],
#        [ 2.05741086e-03],
#        [ 2.67245586e-03],
#        [-1.27682416e-03],
#        [ 1.36440583e-03],
#        [-1.31397124e-03],
#        [-1.43328496e-03],
#        [ 1.13981962e-03],
#        [ 9.23133303e-04],
#        [-1.11103313e-03],
#        [-8.37848280e-04],
#        [-1.65036518e-04],
#        [-6.50668319e-04],
#        [-2.03295905e-03],
#        [-2.67123079e-03],
#        [ 1.76367632e-03],
#        [-4.44647963e-04],
#        [-1.81779303e-04],
#        [-9.05217679e-04],
#        [-3.19178088e-03],
#        [-1.12095710e-03],
#        [ 5.26245065e-03],
#        [ 4.96730888e-03],
#        [-1.32716567e-03],
#        [ 7.29097671e-05],
#        [-6.77579237e-04],
#        [-9.46135881e-04],
#        [-4.39964598e-04],
#        [ 8.47155235e-04],
#        [-1.46651900e-03],
#        [ 1.56445106e-03],
#        [ 2.49913308e-03],
#        [-2.77274292e-03],
#        [ 1.67363803e-03],
#        [ 7.98745781e-04],
#        [ 1.82457702e-03],
#        [ 2.50200207e-03],
#        [ 1.98222176e-03],
#        [-1.08551932e-03],
#        [-1.02955955e-04],
#        [-9.64670122e-05],
#        [-5.12377785e-04],
#        [ 1.24487896e-03],
#        [ 2.65659663e-03],
#        [ 1.70850116e-03],
#        [-1.02670850e-04],
#        [ 4.78177400e-03],
#        [ 3.40764368e-03],
#        [-6.17769214e-04],
#        [-6.09919937e-04],
#        [ 1.24065540e-03],
#        [ 2.22576437e-03],
#        [-2.39565621e-03],
#        [-1.31131612e-03],
#        [-8.61441674e-04],
#        [-2.31319115e-03],
#        [-3.63744324e-04],
#        [-6.71061962e-04],
#        [-9.78367520e-04],
#        [ 7.65644792e-04],
#        [-1.94898115e-03],
#        [ 6.15182216e-04],
#        [-1.25463728e-04],
#        [ 2.49654182e-03],
#        [ 1.96003045e-03],
#        [ 2.17618057e-03],
#        [ 5.52780568e-03],
#        [ 1.21148727e-03],
#        [-1.86084499e-03],
#        [ 3.47949491e-04],
#        [-2.09279136e-03],
#        [-4.27979661e-03],
#        [ 2.10773798e-04],
#        [-1.42719969e-03],
#        [ 5.08055820e-06],
#        [ 1.08369287e-03],
#        [ 2.98127034e-03],
#        [-1.35711895e-03],
#        [ 3.36759456e-03],
#        [-2.19192300e-03],
#        [ 2.14947740e-03],
#        [ 3.50109897e-04],
#        [ 1.98779606e-03],
#        [-1.68075074e-03],
#        [-3.13075530e-03],
#        [ 9.56392654e-04],
#        [-2.62512945e-04],
#        [ 2.38392062e-04],
#        [ 9.33435551e-05],
#        [ 1.21789574e-03],
#        [-2.40967131e-03],
#        [ 7.15147142e-04],
#        [-3.45306344e-03],
#        [ 2.98427709e-03],
#        [ 1.49170907e-03],
#        [ 3.52643674e-03],
#        [ 1.05585167e-03],
#        [ 2.55238941e-03],
#        [-3.38547324e-04],
#        [-2.62309783e-03],
#        [ 2.50897125e-03],
#        [-8.49062776e-04],
#        [-2.26495356e-04],
#        [ 1.53018602e-03],
#        [ 1.28505651e-04],
#        [ 5.12667242e-04],
#        [-5.21854675e-03],
#        [ 5.51785551e-04],
#        [ 3.51193989e-03],
#        [ 3.04070991e-04],
#        [ 1.23340564e-03],
#        [-2.73147460e-04],
#        [-2.72783698e-03],
#        [ 5.37406564e-04],
#        [ 2.14576747e-03],
#        [ 1.78051982e-03],
#        [ 2.36525679e-03],
#        [ 1.41377559e-03],
#        [-1.25146800e-03],
#        [ 2.23295391e-03],
#        [ 5.51283819e-04],
#        [-6.05989721e-03],
#        [ 3.93658350e-03],
#        [ 1.86383913e-03],
#        [-1.88717291e-03],
#        [ 3.98889632e-04],
#        [ 8.72520367e-04],
#        [-6.93595048e-04],
#        [-9.81278969e-04],
#        [-1.21326922e-03],
#        [-3.32398988e-03],
#        [-1.87152871e-04],
#        [ 2.91459124e-04],
#        [ 1.89435614e-03],
#        [ 4.89813266e-03],
#        [-1.44957877e-03],
#        [ 1.47139634e-03],
#        [-2.60312518e-03],
#        [ 2.05336823e-03],
#        [ 6.36816733e-04],
#        [ 1.64552736e-03],
#        [-5.68466962e-04],
#        [ 1.16285852e-03],
#        [-3.87555863e-03],
#        [-2.22776855e-03],
#        [-7.00394054e-04],
#        [ 2.78763945e-04],
#        [ 1.17495818e-03],
#        [-3.01222425e-03],
#        [ 7.15363058e-04],
#        [-3.17242321e-04],
#        [ 1.36956757e-03],
#        [-1.35302827e-03],
#        [-4.23863078e-04],
#        [-3.21827933e-03],
#        [-1.14480194e-03],
#        [-2.30458692e-03],
#        [ 9.72942615e-05],
#        [ 3.06664267e-03],
#        [-9.51926005e-04],
#        [-6.72935485e-05],
#        [ 2.92743509e-03],
#        [-2.15401217e-03],
#        [-4.57146232e-04],
#        [ 2.85103949e-03],
#        [ 2.07387707e-04],
#        [ 1.41809826e-03],
#        [-1.68307324e-04],
#        [-9.75781500e-04],
#        [-3.22741922e-04],
#        [ 2.12737676e-03],
#        [ 1.24161046e-03],
#        [ 6.19570972e-04],
#        [-3.82562684e-03],
#        [-6.89019330e-04],
#        [ 7.23857774e-04],
#        [ 1.06872342e-03],
#        [-1.31368649e-03],
#        [-2.24278107e-04],
#        [-3.34401840e-05],
#        [ 1.08796208e-03],
#        [ 2.66697402e-03],
#        [-2.75189720e-03],
#        [-2.05248201e-03],
#        [-2.01005479e-03],
#        [ 1.91914102e-03],
#        [ 3.20499414e-03],
#        [ 4.73654973e-03],
#        [-2.06250572e-03],
#        [-1.40157921e-03],
#        [-1.76656592e-03],
#        [-2.48716603e-04],
#        [-1.40154572e-03],
#        [-4.06287528e-03],
#        [ 2.62863677e-03],
#        [-1.19283694e-03],
#        [ 1.46090464e-03],
#        [ 2.06411626e-03],
#        [-4.38369696e-04],
#        [-7.99437760e-04],
#        [ 2.28493464e-03],
#        [-1.15751950e-03],
#        [ 4.18333839e-03],
#        [ 1.81893052e-03],
#        [-5.75595394e-04],
#        [-8.66656968e-04],
#        [-1.51411328e-05],
#        [-2.67559308e-04],
#        [ 2.53608068e-03],
#        [-5.97695315e-04],
#        [ 2.11875406e-04],
#        [-3.58932830e-03],
#        [-2.23701599e-03],
#        [ 1.26346444e-03],
#        [ 1.27171864e-03],
#        [ 4.34427161e-04],
#        [ 2.64913691e-04],
#        [-4.44031452e-03],
#        [-2.35960851e-04],
#        [ 1.43269787e-03],
#        [-8.49817194e-04],
#        [-1.66521881e-03],
#        [-2.32249597e-04],
#        [ 5.05320408e-04],
#        [-1.14872805e-03],
#        [-1.36722926e-03],
#        [-5.74889469e-04],
#        [-1.45651144e-03],
#        [ 7.20884419e-04],
#        [ 6.82954138e-04],
#        [-8.27335889e-04],
#        [-3.48033371e-03],
#        [-3.17743849e-03],
#        [-3.01477252e-03],
#        [-9.38723232e-04],
#        [-1.92854115e-03],
#        [ 5.41459677e-04],
#        [ 1.17631291e-03],
#        [-2.88380626e-03],
#        [ 1.25086412e-03],
#        [-2.42169831e-03],
#        [ 9.36162436e-04],
#        [ 4.29381091e-03],
#        [-4.97988051e-04],
#        [-8.57480131e-04],
#        [ 6.30019592e-04],
#        [ 1.98190220e-03],
#        [ 7.16976425e-03],
#        [ 2.22044134e-03],
#        [-5.34004307e-04],
#        [ 1.09898330e-03],
#        [ 3.69682382e-03],
#        [-2.28032526e-03],
#        [ 1.08041291e-03],
#        [ 7.22078930e-04],
#        [-9.50408641e-05],
#        [-6.25587315e-04],
#        [ 4.47368596e-03],
#        [-9.60509894e-05],
#        [-7.76180986e-04],
#        [ 7.89769672e-04],
#        [-1.05182165e-03],
#        [-3.59179442e-04],
#        [-1.32400579e-04],
#        [-1.13603074e-03],
#        [-3.27309380e-04],
#        [ 1.20351542e-03],
#        [ 1.82850783e-03],
#        [-1.16140813e-03],
#        [-1.34115208e-03],
#        [ 1.99039585e-03],
#        [-2.62237956e-03],
#        [ 1.98787520e-03],
#        [ 3.02136138e-03],
#        [ 3.40702115e-03],
#        [-8.07836287e-04],
#        [-3.06670112e-03],
#        [-9.88117677e-04],
#        [ 5.62165177e-03],
#        [-4.08989020e-04],
#        [ 1.39861074e-03],
#        [ 4.87191354e-04],
#        [ 2.68633462e-03],
#        [-1.73778369e-03],
#        [ 4.14615924e-03],
#        [-2.65734306e-03],
#        [ 5.00525044e-03],
#        [-8.69394423e-04],
#        [ 6.73766465e-04],
#        [ 1.33290667e-03],
#        [-4.56761207e-04],
#        [ 2.07683994e-03],
#        [ 1.24825954e-03],
#        [ 1.23577113e-03],
#        [-6.82007961e-04],
#        [ 3.29584715e-04],
#        [-1.75722628e-03],
#        [ 1.40105874e-03],
#        [-7.32392458e-04],
#        [-2.23351169e-03],
#        [-3.28693748e-03],
#        [ 1.83035320e-03],
#        [ 3.88516277e-03],
#        [-6.39172271e-05],
#        [ 4.12089598e-03],
#        [ 2.02050465e-04],
#        [-1.47348791e-03],
#        [-1.07471889e-03],
#        [ 1.26721966e-03],
#        [ 2.05894528e-03],
#        [ 6.02417405e-04],
#        [-2.98678593e-03],
#        [-3.17977298e-03],
#        [ 2.17553673e-03],
#        [ 1.54174273e-03],
#        [ 8.89323282e-04],
#        [-2.43172948e-04],
#        [ 1.57199773e-03],
#        [ 2.04611084e-04],
#        [-9.42098843e-05],
#        [ 3.05306038e-03],
#        [ 2.46863534e-03],
#        [-1.83087225e-03],
#        [-2.46331489e-04],
#        [ 4.93259762e-03],
#        [-2.16773941e-03],
#        [ 3.33996395e-03],
#        [-2.68643801e-03],
#        [-1.53315405e-04],
#        [-4.15860280e-03],
#        [ 1.33462201e-03],
#        [-3.22004921e-03],
#        [-3.36385142e-04],
#        [ 3.05568761e-03],
#        [ 3.74412510e-03],
#        [-2.72986078e-05],
#        [-9.06797926e-04],
#        [-1.37062042e-03],
#        [ 2.32672539e-03],
#        [ 1.79830550e-04],
#        [ 2.80714989e-03],
#        [-1.48365773e-03],
#        [ 2.62409650e-05],
#        [ 2.04675050e-03],
#        [ 2.02925623e-03],
#        [ 1.48490678e-03],
#        [-4.28353442e-04],
#        [ 1.50775188e-03],
#        [ 1.91750225e-03],
#        [ 4.33983534e-03],
#        [ 3.05932186e-03],
#        [ 3.30743681e-03],
#        [-4.66908290e-04],
#        [ 2.36998288e-03],
#        [-1.60794391e-03],
#        [ 2.14895364e-03],
#        [ 1.09315179e-03],
#        [ 1.49225858e-03],
#        [ 4.40289494e-04],
#        [-3.97033606e-04],
#        [-1.84290689e-03],
#        [-3.70938853e-03],
#        [ 9.62115898e-04],
#        [ 1.06739266e-03],
#        [ 4.94575048e-04],
#        [-2.43943203e-03],
#        [-5.03281505e-04],
#        [-3.81749565e-03],
#        [-8.01729705e-04],
#        [ 1.01599031e-03],
#        [ 1.84539113e-03],
#        [ 8.71239259e-04],
#        [ 1.19091927e-03],
#        [ 7.12634662e-04],
#        [-6.14105122e-04],
#        [ 4.54193572e-04],
#        [ 3.24257474e-03],
#        [-1.48003290e-03],
#        [ 1.99550332e-04],
#        [-7.49142970e-05],
#        [ 2.49867886e-03],
#        [-8.93957797e-05],
#        [-1.48547521e-03],
#        [-1.12891696e-03],
#        [ 1.18325048e-03],
#        [ 2.27676100e-04],
#        [ 1.10272165e-03],
#        [ 1.17827703e-04],
#        [ 1.45829286e-03],
#        [ 3.67811150e-03],
#        [-4.26894076e-06],
#        [ 3.14739088e-03],
#        [ 8.42667447e-04],
#        [-1.70996808e-03],
#        [-1.23098793e-03],
#        [ 6.34645225e-04],
#        [-9.02566200e-04],
#        [-2.63872657e-03],
#        [-5.98640781e-04],
#        [ 2.60548516e-03],
#        [ 2.28742572e-03],
#        [-4.92837593e-04],
#        [-1.75757151e-03],
#        [ 5.15198373e-04],
#        [-5.01411357e-04],
#        [ 3.58699825e-03],
#        [-3.16827791e-03],
#        [-4.42218973e-04],
#        [ 2.58726303e-03],
#        [ 4.87509322e-04],
#        [-7.52844009e-04],
#        [ 1.20867405e-03],
#        [ 1.19499850e-03],
#        [ 1.94351468e-03],
#        [-2.40412152e-03],
#        [ 1.49055071e-03],
#        [-2.94758973e-03],
#        [-1.10921849e-03],
#        [ 6.38407194e-04],
#        [ 3.31874350e-04],
#        [ 1.98133119e-03],
#        [-1.34683367e-03],
#        [ 1.78191186e-03],
#        [ 3.73901718e-03],
#        [ 3.79456466e-04],
#        [-4.04887182e-03],
#        [ 3.08331218e-03],
#        [ 4.84404605e-03],
#        [-1.03612781e-03],
#        [-9.30607680e-04],
#        [ 1.03785274e-03],
#        [ 2.00695833e-03],
#        [ 1.05678444e-03],
#        [-2.01285566e-04],
#        [ 5.24801180e-04],
#        [ 1.94717700e-03],
#        [-7.55985141e-04],
#        [-1.08566178e-03],
#        [-4.49140529e-03],
#        [ 1.79671282e-03],
#        [-1.55293378e-04],
#        [ 1.43603796e-04],
#        [ 1.84953466e-03],
#        [-1.75981807e-03],
#        [-2.75390644e-03],
#        [-1.56838036e-03],
#        [ 3.88252177e-03],
#        [ 4.12795131e-05],
#        [ 1.71405867e-03],
#        [ 2.57323984e-03],
#        [-1.58136260e-03],
#        [-1.97428509e-03],
#        [-1.92220870e-03],
#        [ 8.45219450e-04],
#        [ 1.43763934e-04],
#        [-9.00912234e-05],
#        [-2.95430285e-03],
#        [-6.95699587e-04],
#        [-3.41750717e-04],
#        [ 5.31597255e-04],
#        [-2.21136895e-03],
#        [ 7.74831133e-04],
#        [ 2.53659405e-04],
#        [-1.98885779e-03],
#        [-7.31615479e-04],
#        [ 3.39367681e-03],
#        [-2.69058269e-03],
#        [-1.03075468e-03],
#        [ 1.74972437e-03],
#        [-2.39066980e-03],
#        [-1.08716325e-04],
#        [-1.26869439e-03],
#        [-1.54505919e-04],
#        [-2.02487254e-03],
#        [ 4.54838531e-03],
#        [ 4.59216407e-03],
#        [ 3.84301240e-03],
#        [-1.24259270e-04],
#        [ 1.37003591e-03],
#        [ 3.27899521e-03],
#        [-4.00290485e-03],
#        [-9.24274346e-04],
#        [ 4.00301214e-04],
#        [-2.79695689e-03],
#        [-1.25978996e-03],
#        [-1.42362513e-03],
#        [ 1.55134492e-03],
#        [ 5.28371302e-04],
#        [ 2.47556242e-03],
#        [-5.29832800e-04],
#        [-2.42074485e-03],
#        [ 2.64645301e-03],
#        [ 1.53802251e-03],
#        [-4.08437195e-04],
#        [ 2.79597856e-04],
#        [ 1.58458695e-03],
#        [-3.61183252e-03],
#        [ 2.36556401e-03],
#        [-2.10741709e-03],
#        [ 6.14916917e-04],
#        [-1.26471544e-03],
#        [ 3.54593688e-05],
#        [ 8.29441937e-04],
#        [ 4.69761181e-03],
#        [ 1.41049483e-04],
#        [ 6.63182309e-04],
#        [-7.94451260e-04],
#        [-1.16643939e-03],
#        [-5.88769034e-05],
#        [ 1.54478625e-03],
#        [-2.89737461e-03],
#        [-4.41453096e-05],
#        [-5.27101296e-04],
#        [-2.16271241e-03],
#        [ 2.80754788e-03],
#        [-2.12209477e-03],
#        [-5.03143696e-03],
#        [ 2.84907831e-03],
#        [ 2.96313081e-03],
#        [-2.03638457e-03],
#        [-4.91412244e-04],
#        [-2.25644277e-03],
#        [ 2.82985342e-03],
#        [ 1.98457846e-03],
#        [-1.60010671e-04],
#        [ 3.23586136e-04],
#        [ 1.16754082e-03],
#        [ 3.41009558e-03],
#        [-1.01648281e-03],
#        [ 1.85098088e-03],
#        [-7.39346362e-04],
#        [-2.59478901e-03],
#        [ 1.31949225e-03],
#        [ 1.75717574e-03],
#        [-7.85815502e-04],
#        [ 1.90962952e-03],
#        [-5.49846924e-04],
#        [-2.55990305e-03],
#        [ 1.07346594e-03],
#        [-2.03246620e-03],
#        [-5.69274672e-04],
#        [ 3.45628264e-03],
#        [-6.40454267e-04],
#        [-8.35177350e-04],
#        [-3.03789651e-03],
#        [-1.77470829e-03],
#        [-5.40480372e-04],
#        [ 4.49441639e-04],
#        [ 4.42417658e-04],
#        [-4.64017180e-03],
#        [ 2.72142842e-04],
#        [-2.40781732e-03],
#        [ 7.10142878e-04],
#        [ 5.71626391e-04],
#        [ 3.07553094e-04],
#        [-1.72664194e-03],
#        [ 2.36248390e-03],
#        [ 1.62895066e-03],
#        [-8.37276026e-04],
#        [-1.05888258e-03],
#        [ 3.65184247e-03],
#        [ 4.38213021e-04],
#        [ 3.41668471e-04],
#        [ 3.73678306e-03],
#        [-8.18929369e-04],
#        [ 6.84354795e-05],
#        [-1.97906989e-03],
#        [-3.03514804e-03],
#        [-3.88233659e-03],
#        [-1.60242788e-03],
#        [ 4.33177654e-03],
#        [-2.53807988e-03],
#        [-3.27600942e-03],
#        [ 1.68817067e-03],
#        [-5.25424948e-04],
#        [-7.00744351e-04],
#        [ 1.91860510e-03],
#        [ 2.16102949e-03],
#        [-1.83804785e-03],
#        [ 2.65361715e-03],
#        [ 3.04375671e-03],
#        [-5.06252373e-04],
#        [ 5.11582652e-03],
#        [-1.31519089e-03],
#        [ 2.45546738e-03],
#        [-2.07358637e-03],
#        [ 2.80034635e-03],
#        [-8.52224336e-04],
#        [-1.64584968e-03],
#        [ 6.13343154e-05],
#        [ 3.57649670e-03],
#        [-2.24961418e-03],
#        [ 5.51064883e-04],
#        [-3.54055931e-03],
#        [-2.28446231e-03],
#        [ 5.14963538e-04],
#        [ 1.96563246e-03],
#        [-5.69425396e-05],
#        [-7.75614772e-04],
#        [-8.18667711e-04],
#        [-2.96414715e-03],
#        [-4.48087709e-03],
#        [-2.56360178e-04],
#        [ 5.78821080e-04],
#        [ 6.57059029e-04],
#        [ 2.10677165e-04],
#        [-3.76757976e-03],
#        [ 6.75177247e-05],
#        [-1.20453922e-03],
#        [ 4.77636153e-04],
#        [ 5.30468913e-04],
#        [-7.06766023e-04],
#        [-1.87623872e-04],
#        [-2.02078407e-03],
#        [ 1.64513141e-03],
#        [-3.81833321e-04],
#        [ 2.65407794e-03],
#        [ 1.03695097e-03],
#        [-6.34387920e-04],
#        [-1.58243321e-03],
#        [-2.16338236e-03],
#        [-1.66066529e-03],
#        [ 1.67580101e-03],
#        [ 3.74684905e-04],
#        [ 5.46603420e-03],
#        [ 4.82492268e-04],
#        [ 1.59620699e-03],
#        [-3.65600394e-03],
#        [-4.69106975e-03],
#        [ 4.44122774e-03],
#        [ 1.29559226e-03],
#        [ 4.83682427e-05],
#        [ 1.03193161e-03],
#        [-5.78990011e-04],
#        [-2.46729037e-04],
#        [ 1.44376155e-04],
#        [-1.25178472e-03],
#        [-1.05281304e-03],
#        [ 2.81343517e-03],
#        [ 3.79887322e-04],
#        [-4.17799129e-06],
#        [ 2.29055388e-03],
#        [ 2.60010253e-03],
#        [-4.05978815e-03],
#        [ 3.38351924e-04],
#        [-3.33501022e-03],
#        [-7.17767890e-04],
#        [ 2.69333711e-04],
#        [-3.23295790e-04],
#        [-1.63253580e-03],
#        [ 3.38168000e-03],
#        [ 2.06540047e-03],
#        [-4.08197387e-04],
#        [ 4.93193841e-04],
#        [ 9.81212978e-04],
#        [ 1.61252345e-05],
#        [ 1.17613279e-03],
#        [ 1.31155460e-03],
#        [-1.81576976e-04],
#        [ 3.29118546e-03],
#        [ 5.16652499e-04],
#        [ 2.20427729e-03],
#        [ 4.13343582e-04],
#        [-7.92489274e-04],
#        [ 1.94493994e-03],
#        [-1.84476336e-03],
#        [ 1.61299294e-03],
#        [ 2.30485613e-03],
#        [ 7.71397968e-04],
#        [-6.96599756e-04],
#        [-2.48348968e-03],
#        [ 1.48192942e-03],
#        [ 2.49016132e-03],
#        [-2.59465160e-04],
#        [ 1.36189735e-03],
#        [ 9.14657505e-04],
#        [ 2.53863748e-03],
#        [-2.14175380e-03],
#        [ 2.85364417e-03],
#        [ 3.32611636e-03],
#        [ 2.11532205e-03],
#        [ 1.88934228e-03],
#        [-1.11526823e-03],
#        [-1.13825687e-03],
#        [ 2.79630701e-03],
#        [-4.53131204e-03],
#        [ 4.50990179e-04],
#        [ 9.22052568e-04],
#        [ 2.46873366e-03],
#        [-5.93516258e-04],
#        [ 1.49120796e-03],
#        [-5.64664493e-04],
#        [ 1.32386448e-03],
#        [ 7.14452586e-04],
#        [-4.19440216e-04],
#        [-5.18445376e-04],
#        [-3.02349621e-03],
#        [-3.17038689e-03],
#        [ 2.59287658e-03],
#        [-2.20490284e-03],
#        [-2.58376609e-04],
#        [ 3.83194099e-04],
#        [-3.41949882e-03],
#        [ 5.71796832e-04],
#        [-4.70175783e-03],
#        [ 1.36528913e-03],
#        [-2.71503682e-03],
#        [-6.33470520e-04],
#        [ 2.36492381e-03],
#        [ 2.41439881e-03],
#        [-1.22384192e-03],
#        [ 1.18856125e-04],
#        [-6.65620181e-04],
#        [-2.32132535e-04],
#        [ 4.79075002e-04],
#        [ 3.31187291e-03],
#        [ 1.63515859e-03],
#        [-1.65081238e-03],
#        [ 9.78343540e-04],
#        [ 1.74736128e-03],
#        [-1.72013817e-03],
#        [ 2.13152624e-03],
#        [ 7.59609087e-04],
#        [ 1.00782289e-03],
#        [-1.09012044e-03],
#        [ 1.97248431e-03],
#        [ 1.29900428e-03],
#        [-1.80191870e-03],
#        [-7.43389794e-04],
#        [-2.83793788e-04],
#        [-1.90744860e-03],
#        [-7.81386511e-04],
#        [-2.59680810e-04],
#        [ 3.13210231e-03],
#        [-1.05958895e-03],
#        [ 1.88724281e-03],
#        [-1.13481349e-03],
#        [-1.35941107e-03],
#        [-5.31214228e-03],
#        [ 1.92378309e-03],
#        [-4.66807037e-05],
#        [-4.68096673e-05],
#        [-5.48132757e-03],
#        [-6.67882816e-04],
#        [ 7.08015069e-04],
#        [-3.11530624e-04],
#        [ 3.85441012e-05],
#        [-8.47501447e-04],
#        [ 1.55920290e-03],
#        [-4.87143037e-04],
#        [ 1.74277499e-03],
#        [-5.43751089e-04],
#        [ 3.95253634e-03],
#        [-1.23516619e-03],
#        [ 8.25303914e-04],
#        [ 1.40413992e-04],
#        [-1.10869793e-03],
#        [ 1.95448262e-03],
#        [ 1.16312560e-03],
#        [-2.28885817e-03],
#        [-1.41465923e-03],
#        [ 3.75062701e-03],
#        [-1.34805660e-03],
#        [-3.80506062e-03],
#        [ 2.14161844e-03],
#        [ 1.91009786e-03],
#        [-4.66621781e-03],
#        [ 2.70341793e-04],
#        [-1.66596603e-03],
#        [-4.31572449e-03],
#        [-4.18033697e-04],
#        [ 1.08109814e-03],
#        [ 1.11685754e-03],
#        [ 6.47077414e-04],
#        [ 4.06813401e-03],
#        [-4.79679407e-04],
#        [ 2.45759191e-03],
#        [ 3.02369978e-03],
#        [ 2.22676864e-03],
#        [ 2.01477386e-03],
#        [ 9.82055326e-05],
#        [ 3.02944692e-03],
#        [-4.24482858e-03],
#        [ 1.19398269e-03],
#        [-7.13679160e-04],
#        [-3.21527711e-03],
#        [ 4.31423786e-06],
#        [ 1.43134455e-03],
#        [ 1.42271395e-03],
#        [-1.07981268e-03],
#        [ 7.13538739e-04],
#        [-2.99504688e-04],
#        [ 6.55091448e-04],
#        [-8.75436790e-04],
#        [ 2.84612787e-03],
#        [-4.01718356e-03],
#        [-2.93534974e-03],
#        [-3.05078549e-03],
#        [-1.85215896e-03],
#        [-3.24584182e-04],
#        [-3.34581785e-04],
#        [-1.89722638e-04],
#        [-1.56290119e-03],
#        [-8.18147949e-04],
#        [-1.03791722e-03],
#        [-2.28508830e-03],
#        [-1.52409756e-03],
#        [-1.90788558e-03],
#        [-1.77474879e-03],
#        [ 2.87710122e-04],
#        [ 3.26764074e-03],
#        [ 1.04459064e-03],
#        [-9.00211194e-04],
#        [ 2.48125742e-03],
#        [-8.93756358e-04],
#        [ 1.48050487e-03],
#        [-3.73740328e-04],
#        [ 2.43327136e-04],
#        [-1.00888098e-04],
#        [ 1.00637019e-03],
#        [-7.40473816e-04],
#        [-4.84170659e-04],
#        [ 4.86871077e-04],
#        [-4.42325376e-04],
#        [ 2.29192416e-03],
#        [-1.34255362e-04],
#        [-2.59171351e-04],
#        [ 2.46794976e-03],
#        [ 1.13627419e-03],
#        [-2.08215667e-05],
#        [ 2.54708210e-03],
#        [-2.24775061e-03],
#        [ 2.67374425e-03],
#        [-2.33695019e-03],
#        [-1.29185285e-04],
#        [ 1.29679192e-03],
#        [-4.69997286e-04],
#        [ 4.47868675e-04],
#        [-3.29823280e-05],
#        [-4.03439984e-03],
#        [ 4.13162837e-05],
#        [ 1.03114521e-03],
#        [ 2.55008894e-03],
#        [ 1.24543931e-03],
#        [ 4.16107948e-04]])

# %%
s = time()
epsilon = 1e-7
y_hat = sigmoid(np.dot(x,w))
output = -((1-y) * np.log(1-y_hat+epsilon)+y*np.log(y_hat+epsilon))
output = (sigmoid(output*1)) * (1-sigmoid(output*1))
dX = np.dot(x.T,output)
dW1 = np.dot(output,w.T)
e = time()
elapse_back = e - s

# %%
dX[:10]
# Out:
# array([[-285.21504305],
#        [-215.76104956],
#        [-524.01423763],
#        [ 219.47408771],
#        [ 322.51103658],
#        [ 104.32323362],
#        [-323.58733769],
#        [ 379.37180498],
#        [-190.13728372],
#        [ 432.85416215]])

# %%
dW[:10]
# Out:
# array([[ 1.36434259e-03],
#        [-9.07727316e-04],
#        [ 3.82603265e-03],
#        [-3.45556295e-04],
#        [-1.70926384e-05],
#        [-2.15211626e-03],
#        [ 2.66405102e-03],
#        [-4.90124030e-04],
#        [-7.87579779e-05],
#        [-7.62882912e-04]])

# %%
x = np.random.randn(1_000_000, 256)

# %%
h = 1e-5
s = time()
for _ in range(100000000):
    x[100,50] += h
    x[100,50] -= h
e = time()
elapse = e - s

# %%
h = 1e-5
s = time()
for _ in range(100000000):
    tmp = x[100,50]
    x[100,50] += h
    x[100,50] = tmp
e = time()
elapse_tmp = e - s

# %%
elapse - elapse_tmp
# Out:
# 6.078313589096069

# %%
elapse
# Out:
# 47.83647274971008
